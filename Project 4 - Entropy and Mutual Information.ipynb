# %% [markdown]
# # Preprocessing, Entropy and Mutual Information between words

# %% [markdown]
# On this notebook is developed the preprocessing and the logic behing entropy and mutual information estimations, that will be applied to our corpus made by newspaper texts.

# %% [markdown]
# ## Preprocessing: Normalization
#
# First, we are going to define our functions to prepare our data before looking for entropy and mutual information estimations.

# %%
import nltk
from bs4 import BeautifulSoup
import re

# %%
def extract_text_from_corpus(path):
    # Getting corpus from the directory
    corpus = nltk.corpus.PlaintextCorpusReader(path, '.*')
    file_list = corpus.fileids()
    
    # Reuniting all text content from files on the directory
    all_text = ''
    for file in file_list:
        with open(path + file, encoding = 'utf-8') as rfile:
            text = rfile.read()
            all_text += text
    
    # Cleaning HTML tags
    soup = BeautifulSoup(all_text, 'lxml')
    clean_text = soup.get_text()
    clean_text = clean_text.lower()
    
    return clean_text

# %%
def tokenize_by_words(text):
    words = text.split()
    alphabetic_words = list()
    
    for word in words:
        token = []
        for character in word:
            if re.match(r'^[a-záéíóúñü+$]', character):
                token.append(character)
        token = ''.join(token)
        if token != '':
            alphabetic_words.append(token)
    
    return alphabetic_words

def tokenize_by_sents(text):
    tokens = nltk.data.load("tokenizers/punkt/spanish.pickle") 
    sents = tokens.tokenize(text)
    alphabetic_sents = list()
    
    for sent in sents:
        sent_token = tokenize_by_words(sent)
        alphabetic_sents.append(sent_token)
    
    return alphabetic_sents

# %%
def remove_stop_words_from_sents(sents, path = './stopwords_es.txt'):
    with open(path, encoding = 'utf-8') as f:
        stop_words = f.readlines()
        stop_words = [w.strip() for w in stop_words]
        
    clean_sents = list()
    for sent in sents:
        clean_sent = [word for word in sent if word not in stop_words]
        clean_sents.append(clean_sent)
    
    return clean_sents

# %%
def lemmatize_from_sents(text, path = './generate.txt'):
    from pickle import dump
    lemmas = dict()
    with open(path, encoding = 'latin1') as file:
        lines = file.readlines()
        for line in lines:
            line = line.strip()
            if line != '':
                words = line.split()
                token = words[0].strip()
                token = token.replace('#', '')
                lemma = words[-1].strip()
                lemmas[token] = lemma
    
    lemmatized_text = list()
    for sent in text:
        #words = sent.split()
        lemmatized_sent = list()
        for word in sent:
            if word in lemmas.keys():
                lemmatized_sent.append(lemmas[word])
            else:
                lemmatized_sent.append(word)
        
        lemmatized_text.append(lemmatized_sent)

    return lemmatized_text

# %%
def normalize_by_sents(path):
    clean_text = extract_text_from_corpus(path)
    alphabetic_sents = tokenize_by_sents(clean_text)     
    clean_sents = remove_stop_words_from_sents(alphabetic_sents)
    preprocessed_text_sents = lemmatize_from_sents(text = clean_sents)
    #print('\n\033[1mLemmatization from sentence completed\033[0m')
    #print(f'Some words after lemmatization: \n{preprocessed_text_sents[:200]}')
    
    return preprocessed_text_sents

# %%
def preprocessing(path = './../EXCELSIOR_100_files/', by_words = True, by_sents = False):
    if by_words:
        try:
            preprocessed_text_words  = normalize_by_words(path)
            print('\033[1mNormalization by word tokens completed\033[0m')
            #print(f'Some words after normalization: \n{clean_words[:200]}')
            
            return preprocessed_text_words
        
        except Exception as e:
            print('An error has occured: ', e)
    elif by_sents:
        try:
            preprocessed_text_sents = normalize_by_sents(path)
            print('\033[1mNormalization by sentence tokens completed\033[0m')
            #print(f'Some words after normalization: \n{clean_sents[:200]}')

            return preprocessed_text_sents
            
        except Exception as e:
            print('An error has occured: ', e)

# %% [markdown]
# #### Preprocessing with sentence tokens

# %%
preprocessed_text_sents = preprocessing(by_words = False, by_sents = True)
# Out:
# Normalization by sentence tokens completed

# %% [markdown]
# Besides, we are going to make a vocabulary from the preprocessed text made with word tokens.

# %%
preprocessed_text_sents
# Out:
# [['emodhtm',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'monstruoso',
#   'diferencia',
#   'colosistas',
#   'colosismo',
#   'luis',
#   'gutierrez',
#   'gonzalez',
#   'luis',
#   'gutiérrez',
#   'sotomayor',
#   'federico',
#   'arreola',
#   'colosistas',
#   'cabal',
#   'según',
#   'decir',
#   'amigo',
#   'luis',
#   'donaldo'],
#  ['ciertamente',
#   'nombre',
#   'circunstancia',
#   'luis',
#   'donaldo',
#   'colosio',
#   'llenar',
#   'insistentemente',
#   'volumen',
#   'espacio',
#   'medio',
#   'comunicación'],
#  ['renovar',
#   'actualidad',
#   'padecer',
#   'frenético',
#   'vaivén',
#   'ficción',
#   'judicial',
#   'política',
#   'integrar',
#   'disgregar',
#   'metafísicas',
#   'metafísicas',
#   'aún',
#   'luis',
#   'donaldo',
#   'desprender',
#   'envolver',
#   'lado',
#   'espejo'],
#  ['dos',
#   'año',
#   'eterno',
#   'insolvencias',
#   'dar',
#   'dar',
#   'fantasía',
#   'magia',
#   'dónde',
#   'quedar',
#   'bolita',
#   'traer',
#   'pueblo',
#   'hastío',
#   'cansancio'],
#  ['inminencia',
#   'percibir',
#   'ir',
#   'diablo',
#   'quórum',
#   'nacional',
#   'ver',
#   'decidido',
#   'instalar',
#   'sécula',
#   'seculórum',
#   'demanda',
#   'justicia'],
#  ['segundo',
#   'aniversario',
#   'asesinato',
#   'colosismo',
#   'astroso',
#   'luto',
#   'protagónico',
#   'intentar',
#   'empapar',
#   'drama',
#   'colosista',
#   'espeso',
#   'negra',
#   'lágrima',
#   'llorona',
#   'profesional',
#   'velorio',
#   'antigüita',
#   'decir',
#   'heredero',
#   'idea',
#   'derecho',
#   'suponer',
#   'paradigma'],
#  ['trampa',
#   'tender',
#   'esotérico',
#   'colosismo',
#   'presidente',
#   'zedillo',
#   'ponce',
#   'león'],
#  ['amigo',
#   'líder',
#   'mandatario',
#   'dedicar',
#   'culto',
#   'seguimiento',
#   'espiritual',
#   'dar',
#   'satisfacción',
#   'compromiso',
#   'político',
#   'aquel',
#   'contraer'],
#  ['actitud', 'moral', 'propiciar', 'trampa'],
#  ['fulano',
#   'zutano',
#   'decir',
#   'discípulo',
#   'hermano',
#   'compañero',
#   'lucha',
#   'asesorar',
#   'caer'],
#  ['veras',
#   'hacer',
#   'lado',
#   'ver',
#   'cargar',
#   'don',
#   'ernesto',
#   'tropel',
#   'búfalo'],
#  ['llorar', 'mama'],
#  ['colosistas', 'saber', 'querer', 'vergüenza', 'confundido', 'pegar', 'ubre'],
#  ['mal', 'hacer'],
#  ['colosismo', 'repartir', 'mercedes', 'presidenciales'],
#  ['parteaguas', 'brecha', 'insondable', 'separar', 'colosistas', 'colosismo'],
#  ['bando',
#   'luis',
#   'donaldo',
#   'llamar',
#   'decir',
#   'nombre',
#   'respectivo',
#   'cabal',
#   'oportunista'],
#  ['efeméride',
#   'doloroso',
#   'colosismo',
#   'intentar',
#   'constituir',
#   'dogma',
#   'doctrina',
#   'credo',
#   'político'],
#  ['allá',
#   'magdalena',
#   'leer',
#   'lumpen',
#   'histriónico',
#   'ver',
#   'protagonismos',
#   'don',
#   'luis',
#   'colosio',
#   'vencer',
#   'garruda',
#   'presencia',
#   'hilaridad',
#   'incontenible'],
#  ['colosismo', 'bah'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'scalfaro',
#   'aquí',
#   'allá',
#   'juan',
#   'maria',
#   'alponte',
#   'julio',
#   'villa',
#   'gagia',
#   'benito',
#   'mussolini',
#   'recibir',
#   'adolf',
#   'hitler',
#   'viajar',
#   'tren',
#   'italia',
#   'someter',
#   'dictador',
#   'italiano',
#   'larga',
#   'furioso',
#   'requisitoria',
#   'comportamiento',
#   'manifiestamente',
#   'malo',
#   'decir',
#   'tropa',
#   'italiana'],
#  ['alemán',
#   'sentir',
#   'herido',
#   'julio',
#   'sicilia',
#   'desembarcar',
#   'angloamericanos',
#   'base',
#   'militar',
#   'augusta',
#   'rendido'],
#  ['hitler',
#   'exasperar',
#   'querer',
#   'aceptar',
#   'italiano',
#   'querer',
#   'combatir'],
#  ['mediodía', 'día', 'entrevista', 'cortar', 'secretario', 'duce'],
#  ['portar', 'telegrama'],
#  ['voz',
#   'emocionar',
#   'mussolini',
#   'traducir',
#   'alemán',
#   'momento',
#   'enemigo',
#   'bombardear',
#   'romo'],
#  ['muerto', 'herido'],
#  ['julio',
#   'palacio',
#   'venecia',
#   'producir',
#   'partir',
#   'cinco',
#   'tarde',
#   'aquel',
#   'sábado',
#   'sombrío',
#   'acontecimiento',
#   'insólito',
#   'ver',
#   'italia'],
#  ['día',
#   'duce',
#   'presidir',
#   'asir',
#   'creer',
#   'reunión',
#   'rutina',
#   'grande',
#   'consejo',
#   'fascista'],
#  ['rutina'],
#  ['grande',
#   'consejo',
#   'aprobar',
#   'moción',
#   'extraordinario',
#   'moción',
#   'grandi',
#   'dejar',
#   'minoría',
#   'pedir',
#   'poder',
#   'poseer',
#   'duce',
#   'traspasar',
#   'rey'],
#  ['día',
#   'siguiente',
#   'domingo',
#   'mussolini',
#   'acudir',
#   'palacio',
#   'real',
#   'mientras',
#   'escucha',
#   'calle',
#   'abbasso',
#   'mussolini'],
#  ['rey', 'alertar', 'desposeer', 'poder', 'momento', 'duro', 'blando'],
#  ['decir', 'monarca', 'allora', 'tutto', 'finito'],
#  ['sera', 'della', 'mia', 'famiglia'],
#  ['comportar', 'piccolo', 'borghese'],
#  ['grandeza', 'advenedizo', 'poder'],
#  ['ustedes', 'saber'],
#  ['italia', 'mussolini', 'pasar', 'aliado', 'alemán'],
#  ['duce', 'apresar', 'partisanos', 'fusilar', 'huir'],
#  ['junio',
#   'país',
#   'referéndum',
#   'elegía',
#   'institución',
#   'italiano',
#   'votar',
#   'república',
#   'monarquía',
#   'consagrar',
#   'marcia',
#   'romo',
#   'famoso',
#   'marcha',
#   'romo',
#   'mussolini',
#   'fascios',
#   'combate',
#   'convertir',
#   'jefe',
#   'gobierno'],
#  ['comenzar',
#   'italia',
#   'edad',
#   'partido',
#   'consagrar',
#   'democracia',
#   'cristiana',
#   'partido',
#   'mayoritario',
#   'mayoría',
#   'relativo'],
#  ['formar', 'coalición', 'gubernamental', 'tempestad', 'posguerra'],
#  ['nación',
#   'italiana',
#   'pesar',
#   'fragilidad',
#   'gobierno',
#   'realizar',
#   'hazaña',
#   'notable',
#   'económico',
#   'industrial',
#   'mundo',
#   'actual'],
#  ['convertir', 'siete', 'grande'],
#  ['millón',
#   'habitante',
#   'crecimiento',
#   'demográfico',
#   'ingreso',
#   'persona',
#   'dólar',
#   'exportación',
#   'alcanzar',
#   'impresionante',
#   'suma',
#   'millón',
#   'dólar',
#   'importación',
#   'millón'],
#  ['un',
#   'elección',
#   'histórico',
#   'derrumbar',
#   'régimen',
#   'partitocrazia',
#   'entrar',
#   'verdadero',
#   'definición',
#   'estabilidad',
#   'enterrar',
#   'pasado',
#   'presente',
#   'fortalecer'],
#  ['presidente',
#   'oscar',
#   'luigi',
#   'scalfaro',
#   'extraordinario',
#   'inteligencia',
#   'mesura',
#   'dirigir',
#   'periodo',
#   'complejo',
#   'gobierno',
#   'apresta',
#   'elección',
#   'decisivo',
#   'próximo',
#   'mes',
#   'abril'],
#  ['ello',
#   'momento',
#   'mismo',
#   'italia',
#   'ocupar',
#   'presidencia',
#   'rotativo',
#   'seis',
#   'mes',
#   'europa',
#   'scalfaro',
#   'hoy',
#   'ascender',
#   'nivel',
#   'hombre',
#   'crear',
#   'ceniza',
#   'primero',
#   'república',
#   'cimiento',
#   'segunda'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'jabón',
#   'olor',
#   'supremo',
#   'lavamanos',
#   'javier',
#   'romero',
#   'cada',
#   'habla',
#   'feria',
#   'según',
#   'ir'],
#  ['tan', 'socorrer', 'refrán', 'elevar', 'vez', 'cima', 'política'],
#  ['quién',
#   'definitivo',
#   'favorecer',
#   'fallo',
#   'corte',
#   'supremo',
#   'diferendo',
#   'gobernador',
#   'tabasco',
#   'procurador',
#   'república'],
#  ['juzgar',
#   'reaccionar',
#   'cada',
#   'habla',
#   'según',
#   'interesar',
#   'simpatía',
#   'antipatía',
#   'política',
#   'mismo',
#   'decir',
#   'madrazo',
#   'secar',
#   'madrazo',
#   'salir',
#   'bien',
#   'librar',
#   'declarar',
#   'empate'],
#  ['cierto',
#   'asunto',
#   'originar',
#   'ardid',
#   'aporrear',
#   'gobernador',
#   'esperar',
#   'dar',
#   'pie',
#   'verso',
#   'forzado',
#   'ir',
#   'dilucidar',
#   'papel',
#   'corte',
#   'tribunal',
#   'legalidad'],
#  ['queda', 'aún', 'ver'],
#  ['sobreseimiento', 'esencial', 'supremo', 'eludir', 'fondo', 'intríngulis'],
#  ['vulgar',
#   'mil',
#   'vez',
#   'decir',
#   'pasado',
#   'supremo',
#   'jurista',
#   'optar',
#   'lavar',
#   'mano'],
#  ['aunque',
#   'ahora',
#   'despedir',
#   'olor',
#   'jabón',
#   'fino',
#   'atisbar',
#   'palangana',
#   'través',
#   'grieta',
#   'procedimiento'],
#  ['dijérase',
#   'aferrar',
#   'tesis',
#   'viejo',
#   'constituyente',
#   'desear',
#   'corte',
#   'impoluta',
#   'nunca',
#   'manchar',
#   'mezquindades',
#   'sucio',
#   'política',
#   'pesar',
#   'vivir',
#   'tiempo',
#   'pedir',
#   'cantar',
#   'real',
#   'vigencia',
#   'triada',
#   'poder',
#   'constitucional',
#   'sometimientos'],
#  ['hacer',
#   'bueno',
#   'titipuchal',
#   'año',
#   'mero',
#   'presidente',
#   'además',
#   'caudillo',
#   'obregón',
#   'poner',
#   'supremo',
#   'brete'],
#  ['antecesor',
#   'huerta',
#   'dejado',
#   'efecto',
#   'desconocimiento',
#   'gobernador',
#   'michoacán',
#   'decretar',
#   'senado',
#   'evidente',
#   'trampa'],
#  ['obregón',
#   'querer',
#   'embarcar',
#   'corte',
#   'pedir',
#   'dilucidar',
#   'embrollo',
#   'seguro',
#   'seguir',
#   'aversión',
#   'múgica'],
#  ['supremo',
#   'enjabonada',
#   'decir',
#   'incompetente',
#   'dejar',
#   'desafío',
#   'fuerza',
#   'caudillesca'],
#  ['durar', 'aquellos', 'tenue', 'arresto', 'autonomía'],
#  ['prudente',
#   'día',
#   'pleno',
#   'maximato',
#   'callista',
#   'supremo',
#   'dar',
#   'baño',
#   'cuerpo',
#   'entero',
#   'evadir',
#   'escándalo',
#   'demandar',
#   'intervenir',
#   'destierro',
#   'luis',
#   'cabrera',
#   'reo',
#   'conferencia',
#   'crítica'],
#  ['célebre',
#   'rasgo',
#   'pundonor',
#   'ministro',
#   'alberto',
#   'vázquez',
#   'mercado',
#   'tirar',
#   'toga',
#   'hacer',
#   'cómplice',
#   'prudencia',
#   'miedo'],
#  ['dudar',
#   'celebrar',
#   'nueva',
#   'independencia',
#   'informe',
#   'zedillo',
#   'observar',
#   'nunca',
#   'vista',
#   'jamás',
#   'oída',
#   'carantoña',
#   'presidente',
#   'supremo',
#   'don',
#   'aguinaco',
#   'prodigar',
#   'supremo',
#   'señor',
#   'lambiscón',
#   'diputado'],
#  ['pensar',
#   'acaso',
#   'emilio',
#   'rabasa',
#   'negar',
#   'judicial',
#   'carácter',
#   'poder',
#   'reducir',
#   'departamento',
#   'jurídico'],
#  ['parecer',
#   'resucitar',
#   'ahora',
#   'fallo',
#   'salomónico',
#   'aforismo',
#   'leguleyo',
#   'corte',
#   'vencer',
#   'convencer'],
#  ['esperar', 'mejorar', 'prueba'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'dinero',
#   'banquero',
#   'santiago',
#   'genoves'],
#  ['pena',
#   'malo',
#   'pena',
#   'querer',
#   'quitar',
#   'venir',
#   'venir',
#   'saber',
#   'dónde',
#   'agua',
#   'mar',
#   'flor',
#   'mayo',
#   'viento',
#   'bosque',
#   'venir',
#   'quedar',
#   'corazón',
#   'amargo',
#   'corteza',
#   'verde',
#   'verde',
#   'limón'],
#  ['respeto',
#   'elevado',
#   'investidura',
#   'parecer',
#   'hombre',
#   'bueno',
#   'honesto',
#   'bienintencionado',
#   'trabajador',
#   'sentir',
#   'simpatía',
#   'hacia',
#   'señor',
#   'presidente',
#   'zedillo'],
#  ['ir',
#   'hacia',
#   'pasado',
#   'ex',
#   'salinas',
#   'apenas',
#   'si',
#   'tardíamente',
#   'llegar',
#   'borde',
#   'chiapas'],
#  ['un',
#   'hora',
#   'sólo',
#   'decimos',
#   'méxico',
#   'tapar',
#   'ojo',
#   'macho',
#   'salir',
#   'inmediato',
#   'suiza',
#   'grande',
#   'reunión',
#   'banquero'],
#  ['allí',
#   'pues',
#   'pretender',
#   'aunque',
#   'viento',
#   'marea',
#   'pasar',
#   'presidente',
#   'omc'],
#  ['poderoso',
#   'caballero',
#   'don',
#   'dinero',
#   'ayer',
#   'decir',
#   'pascual',
#   'si',
#   'casar',
#   'inés',
#   'interés',
#   'sino',
#   'capital'],
#  ['presidente', 'zedillo', 'europa'],
#  ['fundamentalmente', 'tratar', 'aspecto', 'económicofinancieros'],
#  ['hacer', 'un', 'semana', 'lix', 'convención', 'banca', 'cancún'],
#  ['asir', 'pasada', 'convención', 'chiapas', 'ezln'],
#  [],
#  [],
#  ['decir',
#   'querida',
#   'amiga',
#   'rosario',
#   'guerra',
#   'excelsior',
#   'si',
#   'tronar',
#   'sistema',
#   'financiero',
#   'tronar'],
#  ['amiga',
#   'rosario',
#   'si',
#   'romper',
#   'puente',
#   'poder',
#   'atravesar',
#   'remo',
#   'barca',
#   'panga'],
#  ['manera', 'actuar', 'quebrar', 'miles', 'mediana', 'micro', 'empresa'],
#  ['quedar', 'trabajo', 'ciento', 'miles', 'mexicano'],
#  ['salvar', 'navío', 'casi', 'nadie', 'viva'],
#  ['convención',
#   'cancún',
#   'sólo',
#   'banquero',
#   'economista',
#   'financiero',
#   'político',
#   'disponer',
#   'vida'],
#  ['sociólogo',
#   'psicólogo',
#   'filósofo',
#   'etcétera',
#   'allí',
#   'lugar',
#   'tratar',
#   'tratar',
#   'fondo',
#   'vida',
#   'social',
#   'méxico'],
#  ['zea', 'gonzález', 'casanova', 'sánchez', 'soso', 'etcétera', 'decir'],
#  ['creer', 'mayor', 'parte'],
#  ['ésta', 'pena'],
#  ['pena', 'dinero', 'dinero', 'dinero'],
#  ['chiapas', 'apenas', 'si', 'cuenta'],
#  ['cuenta', 'convención', 'banquero'],
#  ['allí',
#   'deber',
#   'sobrio',
#   'sabio',
#   'sergio',
#   'peña',
#   'historia',
#   'capitalismo',
#   'méxico'],
#  ['erradísimo', 'error'],
#  ['ello'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'nacionalista',
#   'natalio',
#   'vázquez',
#   'pallares',
#   'oscar',
#   'gonzalez',
#   'lopez',
#   'marzo',
#   'hacer',
#   'quince',
#   'año',
#   'brusco',
#   'intempestivamente',
#   'terminar',
#   'fecundar',
#   'vida',
#   'mexicano',
#   'excepcional',
#   'nacido',
#   'coalcomán',
#   'población',
#   'tarasca',
#   'cuna',
#   'compatriota',
#   'ilustre',
#   'ricardo',
#   'torre',
#   'gaytán',
#   'relación',
#   'estrechar',
#   'fructífero',
#   'michoacán',
#   'patria'],
#  ['llamar',
#   'llama',
#   'natalio',
#   'vázquez',
#   'pallares',
#   'cardenista',
#   'año',
#   'máximo',
#   'fulgor',
#   'revolución',
#   'mexicana',
#   'cardenista',
#   'después',
#   'cardenista',
#   'siempre'],
#  ['natalio', 'combatiente', 'lúcido', 'tenaz', 'último', 'día'],
#  ['página',
#   'editorial',
#   'excelsior',
#   'dejar',
#   'clara',
#   'enseñanza',
#   'historia',
#   'patria',
#   'sobrado',
#   'muestra',
#   'capacidad',
#   'teórica',
#   'crear',
#   'desarrollar',
#   'tesis',
#   'fundamental',
#   'proyecto',
#   'constitucional',
#   'desarrollo',
#   'febrero',
#   'nacionalismo',
#   'revolucionario',
#   'reconquista',
#   'méxico',
#   'delinear',
#   'texto',
#   'original',
#   'artículo',
#   'tercero',
#   'carta',
#   'magana',
#   'elaborar',
#   'representante',
#   'pueblo',
#   'arma',
#   'triunfante',
#   'formidable',
#   'insurrección',
#   'dictadura',
#   'porfirista',
#   'siniestro',
#   'renovar',
#   'golpista',
#   'febrero',
#   'polichinela',
#   'henry',
#   'lane',
#   'wilson',
#   'embajador',
#   'imperio',
#   'general',
#   'bien',
#   'visto',
#   'buena',
#   'conciencia',
#   'jerarquía',
#   'católica'],
#  ['natalio',
#   'surgir',
#   'dirigente',
#   'juvenil',
#   'legendario',
#   'mítico',
#   'frente',
#   'estudiantil',
#   'socialista',
#   'occidente'],
#  ['luego', 'convergencia', 'primaveral', 'confederación', 'joven', 'méxico'],
#  ['ingresar',
#   'gusto',
#   'orgullo',
#   'partido',
#   'revolución',
#   'mexicana',
#   'renovación',
#   'espléndido',
#   'pnr',
#   'callista'],
#  ['instinto',
#   'popular',
#   'advertir',
#   'transformación',
#   'prm',
#   'pri',
#   'significar',
#   'advenimiento',
#   'pandilla',
#   'contrarrevolucionaria',
#   'enemiga',
#   'agraristas',
#   'corriente',
#   'sindical',
#   'comunista',
#   'lombardista',
#   'pandilla',
#   'alemanista'],
#  ['fuerza',
#   'incontrastable',
#   'cardenismo',
#   'presente',
#   'junio',
#   'llevar',
#   'pesar',
#   'encono',
#   'grupo',
#   'comandado',
#   'jarocho',
#   'sayula',
#   'candidatura',
#   'diputación',
#   'federal',
#   'primavera',
#   'triunfar',
#   'ampliamente',
#   'necesidad',
#   'casilla',
#   'zapato',
#   'acarreo',
#   'votante',
#   'carruseles',
#   'taqueos',
#   'compra',
#   'voto'],
#  ['hoy',
#   'quince',
#   'año',
#   'partida',
#   'física',
#   'natalio',
#   'recordar',
#   'conducta',
#   'viril',
#   'gallardo',
#   'actitud',
#   'diputado',
#   'federal',
#   'denunciar',
#   'calidad',
#   'presidente',
#   'comisión',
#   'petróleo',
#   'cámara',
#   'diputado',
#   'firma',
#   'contrato',
#   'riesgo',
#   'pemex',
#   'compañía',
#   'privado',
#   'estadunidenses'],
#  ['artículo',
#   'memorable',
#   'escribir',
#   'verano',
#   'aportar',
#   'legó',
#   'tarea',
#   'patriótico',
#   'rango',
#   'histórico'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'medio',
#   'educación',
#   'pasa',
#   'allí',
#   'margarita',
#   'michelena',
#   'casi',
#   'mismo',
#   'tiempo',
#   'contribuyente',
#   'descubrir',
#   'hermanita',
#   'procurador',
#   'lozano',
#   'gracia',
#   'andar',
#   'pasear',
#   'protegida',
#   'escolta',
#   'guaruras',
#   'mientras',
#   'humilde',
#   'ciudadano',
#   'despanzurra',
#   'delincuente',
#   'cualquier',
#   'esquina',
#   'doctor',
#   'zedillo',
#   'decir',
#   'claro',
#   'medio',
#   'deber',
#   'vehículo',
#   'educación',
#   'moralización',
#   'pueblo'],
#  ['tan', 'cierto'],
#  ['hablar', 'ahora', 'medio', 'particularmente', 'televisión', 'radio'],
#  ['televisión',
#   'ir',
#   'ahora',
#   'dañoso',
#   'hacer',
#   'sino',
#   'atentar',
#   'valorar',
#   'moral',
#   'inteligencia'],
#  ['ahí',
#   'ir',
#   'lejos',
#   'programa',
#   'deleznable',
#   'hoy',
#   'daniela',
#   'soler',
#   'presentar',
#   'individuillos',
#   'toda',
#   'laya'],
#  ['día',
#   'aparecer',
#   'pantalla',
#   'golfales',
#   'importación',
#   'llamada',
#   'martha',
#   'sánchez',
#   'ningún',
#   'respeto',
#   'público',
#   'relatar',
#   'chiste',
#   'soez',
#   'todas',
#   'letra',
#   'cuya',
#   'causa',
#   'todavía',
#   'arder',
#   'mucha',
#   'oreja'],
#  ['violación',
#   'ley',
#   'federal',
#   'radio',
#   'televisión',
#   'bastar',
#   'tiempo',
#   'programa',
#   'cosa',
#   'llamar',
#   'programa',
#   'salir',
#   'aire',
#   'ipso',
#   'facto'],
#  ['toda',
#   'televisión',
#   'buena',
#   'parte',
#   'radio',
#   'invadir',
#   'cosa',
#   'inmundo',
#   'intimamente',
#   'shanik',
#   'cada',
#   'vez',
#   'abundante',
#   'programa',
#   'nota',
#   'roja'],
#  ['decir',
#   'si',
#   'toda',
#   'basura',
#   'solo',
#   'programa',
#   'informe',
#   'cultivar',
#   'salvo',
#   'programa',
#   'noticiosos'],
#  ['telenovelas',
#   'vehículo',
#   'seguro',
#   'llenar',
#   'masa',
#   'imbecilidad',
#   'ahí',
#   'ir',
#   'premio',
#   'mayor',
#   'maría',
#   'barrio',
#   'dos',
#   'bodrios',
#   'deber',
#   'vergonzoso',
#   'transmitir'],
#  ['ver',
#   'existir',
#   'monitoreo',
#   'alguno',
#   'autoridad',
#   'competente',
#   'material',
#   'utilizar',
#   'televisión'],
#  ['manera', 'vergüenza', 'público', 'llegar', 'hogar', 'asir'],
#  ['poder',
#   'hablar',
#   'competencia',
#   'referir',
#   'televisión',
#   'azteca',
#   'buena',
#   'ley',
#   'posible'],
#  ['comprador',
#   'privado',
#   'canal',
#   'hacer',
#   'sino',
#   'copiar',
#   'mal',
#   'televisar'],
#  ['dos',
#   'grande',
#   'canal',
#   'pasar',
#   'material',
#   'calidad',
#   'vez',
#   'maravilloso',
#   'gracia',
#   'pues',
#   'trata',
#   'frecuencia',
#   'pagado',
#   'gobierno',
#   'medio',
#   'masivo',
#   'comunicación',
#   'referir',
#   'presidente',
#   'día',
#   'cumplir',
#   'año',
#   'organización',
#   'televisión',
#   'iberoamericana',
#   'oti',
#   'señor',
#   'cañedo',
#   'tratar',
#   'aprovechar',
#   'viaje',
#   'toro',
#   'arrancar',
#   'presidente',
#   'elogio',
#   'funesto',
#   'obra',
#   'televisión',
#   'privado'],
#  ['cierto',
#   'público',
#   'necesitar',
#   'entretenimiento',
#   'confundir',
#   'diversión',
#   'degradación',
#   'someter',
#   'auditorio',
#   'muchísimas',
#   'hora',
#   'diario',
#   'presentar',
#   'cosa',
#   'aberrantes',
#   'si',
#   'tratar',
#   'natural',
#   'correcto',
#   'mundo',
#   'sazonar',
#   'despropósito',
#   'creer',
#   'falso',
#   'ídolo',
#   'falso',
#   'valorar'],
#  ['ver',
#   'forma',
#   'cumplir',
#   'televisión',
#   'primero',
#   'cometido',
#   'educar',
#   'cuenta',
#   'recurso',
#   'si',
#   'descontar',
#   'talento'],
#  ['asir',
#   'muestra',
#   'escatología',
#   'violencia',
#   'fomentar',
#   'conducta',
#   'delictuoso',
#   'sofocar'],
#  ['hora',
#   'pedir',
#   'cuenta',
#   'televisión',
#   'privado',
#   'fechorías',
#   'impune',
#   'causa',
#   'ésta',
#   'contaminar',
#   'ambiente',
#   'moral',
#   'ir',
#   'malvivir',
#   'menos',
#   'momento'],
#  ['televisión', 'privado', 'funcionar', 'concesión', 'federal', 'decir'],
#  ['correspondencia',
#   'apartado',
#   'postal',
#   'ciudad',
#   'número',
#   'fax',
#   'editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'camino',
#   'hambruna',
#   'tocar',
#   'fondo',
#   'fernando',
#   'cesarman',
#   'mazorca',
#   'doblar'],
#  ['frecuencia',
#   'escuchar',
#   'discurso',
#   'economista',
#   'político',
#   'tocar',
#   'fondo'],
#  ['poder', 'hundir', 'crisis'],
#  ['quién', 'saber', 'tocar', 'fondo'],
#  ['hoy', 'vivir', 'amenaza', 'brote', 'hambruna'],
#  ['gravedad',
#   'crisis',
#   'económico',
#   'sumar',
#   'tremendo',
#   'sequía',
#   'norte',
#   'insuficiencia',
#   'producción',
#   'alimento',
#   'erosión',
#   'tierra',
#   'muerte',
#   'ganado',
#   'falta',
#   'previsión',
#   'evitar',
#   'catástrofe',
#   'llevar',
#   'rincón',
#   'hambruna'],
#  ['cuándo', 'toca', 'fondo'],
#  ['terrible',
#   'despertar',
#   'noticia',
#   'sierra',
#   'tal',
#   'lugar',
#   'grupo',
#   'poblador',
#   'comer',
#   'causa',
#   'sequía',
#   'condicionar',
#   'política',
#   'extremar',
#   'pobreza',
#   'deforestación',
#   'arroyo',
#   'seco',
#   'esqueleto',
#   'chivo',
#   'gente',
#   'hambre',
#   'niño',
#   'flaco',
#   'madre',
#   'huesudo',
#   'hombre',
#   'viejo',
#   'transparente'],
#  ['hambruna',
#   'brutal',
#   'sufrir',
#   'profundo',
#   'vergüenza',
#   'pueblo',
#   'padecer'],
#  ['hambruna', 'encontrar', 'extremo', 'espectro', 'ecocidio'],
#  ['suceder', 'desequilibrio', 'hombre', 'paisaje', 'total'],
#  ['destrozo', 'casa'],
#  ['final', 'utópico', 'fantasía', 'armonía', 'hombre', 'medio'],
#  ['fracaso', 'sociedad', 'fracaso', 'sistema', 'político'],
#  ['fracaso', 'humillación', 'humanismo', 'contener', 'proyecto', 'patria'],
#  ['suceder', 'sierra', 'tarahumara', 'seguir', 'suceder'],
#  ['hacer',
#   'dos',
#   'año',
#   'presenciar',
#   'drama',
#   'hambre',
#   'sierra',
#   'pronto',
#   'reacción',
#   'autoridad'],
#  ['embargo', 'problema', 'continuar', 'regar', 'toda', 'superficie', 'país'],
#  ['rincón',
#   'escape',
#   'presencia',
#   'niño',
#   'adulto',
#   'desnutridos',
#   'padecer',
#   'hambre',
#   'crónica'],
#  ['aumento',
#   'precio',
#   'producto',
#   'alimenticio',
#   'básico',
#   'leche',
#   'azúcar',
#   'ahora',
#   'tortilla',
#   'acelerar',
#   'escasez',
#   'alimento',
#   'habitante',
#   'pobre'],
#  ['declaración',
#   'oficial',
#   'justificar',
#   'aumento',
#   'terminar',
#   'costoso',
#   'subsidio',
#   'pronto',
#   'después',
#   'año',
#   'dar',
#   'cuenta',
#   'regular',
#   'precio',
#   'controlar',
#   'subsidio',
#   'subsidio',
#   'beneficiar',
#   'salario',
#   'adecuado',
#   'además',
#   'existir',
#   'corrupción',
#   'manejo'],
#  ['saber',
#   'economista',
#   'sino',
#   'sólo',
#   'tratar',
#   'entender',
#   'dificultad',
#   'manejo',
#   'dinero',
#   'perspectiva',
#   'subsidio',
#   'regalo',
#   'población',
#   'sino',
#   'simplemente',
#   'forma',
#   'compensar',
#   'pésimo',
#   'salario'],
#  ['asir',
#   'malo',
#   'ingreso',
#   'poder',
#   'adquirir',
#   'cantidad',
#   'adecuado',
#   'producto',
#   'subsidiar',
#   'además',
#   'poder',
#   'utilizar',
#   'servicio',
#   'subsidiar',
#   'transporte'],
#  ['hoy',
#   'enfrentar',
#   'grave',
#   'situación',
#   'subsidio',
#   'tienden',
#   'eliminar',
#   'sueldo',
#   'seguir',
#   'raquítico',
#   'aún',
#   'deplorable',
#   'subida',
#   'precio',
#   'aquellos',
#   'insumos',
#   'subsidiar'],
#  ['constituir', 'catástrofe', 'ecológico'],
#  ['pobreza',
#   'signo',
#   'degradación',
#   'posibilidad',
#   'pueblo',
#   'conseguir',
#   'pobreza',
#   'escasez',
#   'producto',
#   'indispensable',
#   'subsistencia'],
#  ['grave', 'además', 'precio', 'predicción', 'producción', 'grano'],
#  ['embargo', 'absurdamente', 'tranquilo'],
#  ['si', 'pasar'],
#  ['grave', 'vivir', 'geranio', 'tierra'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'hacer',
#   'año',
#   'abril',
#   'fuerza',
#   'estadunidenses',
#   'británica',
#   'registrar',
#   'casa',
#   'población',
#   'situar',
#   'parte',
#   'occidental',
#   'alemania',
#   'austria',
#   'objeto',
#   'detener',
#   'cerca',
#   'mil',
#   'alemán',
#   'sospecha',
#   'implicar',
#   'rebelión',
#   'nazi'],
#  ['ninguno', 'soldado', 'resultar', 'herido'],
#  ['sindicato',
#   'trabajador',
#   'industria',
#   'cinematográfico',
#   'perder',
#   'laudo',
#   'laboral',
#   'sindicato',
#   'encabezar',
#   'cantinflas',
#   'jorge',
#   'negrete',
#   'según',
#   'segunda',
#   'agrupación',
#   'poder',
#   'filmar',
#   'película',
#   'interponer',
#   'recurso',
#   'obligar',
#   'juez',
#   'primero',
#   'distrito',
#   'administrativo',
#   'licenciado',
#   'ponciano',
#   'hernández',
#   'ortega',
#   'pedir',
#   'presidente',
#   'república',
#   'decir',
#   'si',
#   'opinión',
#   'emitir',
#   'respecto',
#   'conflicto',
#   'cinematografistas',
#   'simple',
#   'opinión',
#   'decir',
#   'si',
#   'característica',
#   'fallo',
#   'arbitral'],
#  ['ello',
#   'depender',
#   'justicia',
#   'federal',
#   'decidir',
#   'si',
#   'amparo',
#   'promover',
#   'stic',
#   'laudo',
#   'procedente'],
#  ['vez',
#   'organizado',
#   'legalmente',
#   'concluir',
#   'estructura',
#   'administrativa',
#   'partido',
#   'político',
#   'sólo',
#   'quedar',
#   'candidato',
#   'presidenciales',
#   'fuerza',
#   'debidamente',
#   'organizado',
#   'licenciado',
#   'miguel',
#   'alemán',
#   'ezequiel',
#   'padilla'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'hacer',
#   'año',
#   'teniente',
#   'william',
#   'calley',
#   'sentenciar',
#   'cadena',
#   'perpetua',
#   'tribunal',
#   'militar',
#   'juzgar',
#   'considerar',
#   'culpable',
#   'asesinato',
#   'menos',
#   'hombre',
#   'mujer',
#   'niño',
#   'vietnamita',
#   'my',
#   'lai',
#   'hacer',
#   'tres',
#   'año'],
#  ['apelación', 'automática', 'trámite', 'poder', 'demorar', 'varios', 'mes'],
#  ['presidente',
#   'tribunal',
#   'coronel',
#   'reid',
#   'kennedy',
#   'decir',
#   'jurado',
#   'leer',
#   'veredicto',
#   'comprender',
#   'señor',
#   'agonía',
#   'deber',
#   'haber',
#   'pasado',
#   'ustedes',
#   'mismos',
#   'oficial'],
#  ['agradecer'],
#  ['luego',
#   'ordenar',
#   'escribano',
#   'lectura',
#   'veredicto',
#   'teniente',
#   'william',
#   'calley',
#   'presidente',
#   'corte',
#   'deber',
#   'informar',
#   'tribunal',
#   'condena',
#   'encarcelar',
#   'trabajo',
#   'forzado',
#   'tiempo',
#   'durar',
#   'vida',
#   'natural',
#   'dar',
#   'baja',
#   'ejército',
#   'privado',
#   'haber',
#   'indemnizaciones'],
#  ['calley',
#   'poner',
#   'pie',
#   'cuadrar',
#   'militarmente',
#   'escuchar',
#   'sentencia'],
#  ['reacción',
#   'cadena',
#   'caracterizar',
#   'campaña',
#   'anular',
#   'veredicto',
#   'elevación',
#   'protesta',
#   'funcionario',
#   'asir',
#   'solicitud',
#   'formal',
#   'clemencia',
#   'militar',
#   'ex',
#   'soldado',
#   'persona',
#   'hijo',
#   'pelear',
#   'vietnam'],
#  ['parte',
#   'hombre',
#   'nueva',
#   'york',
#   'enviar',
#   'telegrama',
#   'decir',
#   'colgar',
#   'calley'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxarthtml',
#   'excelsior',
#   'editorial',
#   'martes',
#   'abril',
#   'ningún',
#   'caso',
#   'modificar',
#   'rumbo',
#   'cuento',
#   'político',
#   'francisco',
#   'martin',
#   'moreno',
#   'señor',
#   'responder',
#   'coro',
#   'unísono',
#   'si',
#   'echar',
#   'andar',
#   'economía',
#   'aun',
#   'lograr',
#   'aumentar',
#   'índice',
#   'inflación',
#   'poder',
#   'aumentar',
#   'peligrosamente',
#   'efervescencia',
#   'social'],
#  ['poder', 'señor', 'tener', 'disciplina', 'nación', 'desarrollar'],
#  ['requerir',
#   'encontrar',
#   'dosis',
#   'término',
#   'medio',
#   'crecer',
#   'ir',
#   'dominar',
#   'gradualmente',
#   'inflación'],
#  ['ningún', 'caso', 'variar', 'rumbo'],
#  ['señor',
#   'vivir',
#   'estanflación',
#   'mezcla',
#   'explosivo',
#   'estancamiento',
#   'económico',
#   'inflación'],
#  ['peor', 'dos', 'mundo'],
#  ['empresa',
#   'difícilmente',
#   'poder',
#   'resistir',
#   'tiempo',
#   'oxígeno',
#   'crédito',
#   'venta',
#   'recuperación',
#   'cartera'],
#  ['escasamente', 'hacer', 'negocio'],
#  ['poco', 'poco', 'dinero'],
#  ['poco',
#   'poco',
#   'cumplir',
#   'obligación',
#   'bancario',
#   'fiscal',
#   'insuficiencia',
#   'financiero',
#   'generar',
#   'utilidad',
#   'ende',
#   'causar',
#   'impuesto'],
#  ['empresa', 'pobre', 'fisco', 'pobre', 'país', 'pobre', 'señor'],
#  ['inaplazable',
#   'gastar',
#   'gobierno',
#   'acertado',
#   'medianía',
#   'empezar',
#   'crecer',
#   'ningún',
#   'caso',
#   'variar',
#   'rumbo'],
#  ['señor',
#   'usted',
#   'razonable',
#   'correcto',
#   'hacer',
#   'cualquier',
#   'esfuerzo',
#   'tal',
#   'detener',
#   'inflación',
#   'dañar',
#   'altísimo',
#   'imponer',
#   'social',
#   'comunidad'],
#  ['sólo',
#   'empresa',
#   'sólo',
#   'contratar',
#   'nadie',
#   'sino',
#   'despedir',
#   'masivamente',
#   'personal',
#   'tal',
#   'sobrevivir'],
#  ['gente',
#   'perder',
#   'empleo',
#   'asfixia',
#   'económico',
#   'impotencia',
#   'financiero',
#   'extremo',
#   'poder',
#   'pagar',
#   'colegiatura',
#   'hijo',
#   'constituir',
#   'duda',
#   'invitación',
#   'violencia'],
#  ['pronto',
#   'escoger',
#   'control',
#   'inflación',
#   'manifestación',
#   'urbana',
#   'ciudadano',
#   'dispuesto',
#   'familia',
#   'perecer',
#   'hambre'],
#  ['ningún', 'caso', 'variar', 'rumbo'],
#  ['suelte',
#   'gasto',
#   'señor',
#   'suéltelo',
#   'aun',
#   'conceder',
#   'aumento',
#   'salarial',
#   'sufrir',
#   'nuevo',
#   'incremento',
#   'precio',
#   'bien',
#   'servicio',
#   'prestar'],
#  ['menos',
#   'parálisis',
#   'estancamiento',
#   'postración',
#   'nacional',
#   'encontrar'],
#  ['ahí', 'salir', 'bueno', 'señor'],
#  ['alejar',
#   'libro',
#   'texto',
#   'alejar',
#   'tesis',
#   'doctorado',
#   'pensar',
#   'hombre'],
#  ['hacer', 'detener', 'teoría', 'económico'],
#  ['sequía',
#   'financiero',
#   'promover',
#   'banco',
#   'méxico',
#   'demoledor',
#   'inhumano',
#   'incendiaria'],
#  ['éxito',
#   'aplicación',
#   'fascista',
#   'entonces',
#   'mexicano',
#   'demostrar',
#   'catastrófico',
#   'error',
#   'señor',
#   'ningún',
#   'caso',
#   'variar',
#   'rumbo'],
#  ['paciente', 'ser', 'señor'],
#  ['dar', 'agua', 'morir'],
#  ['sobra', 'saber', 'conveniente', 'señor', 'muerte'],
#  ['salvar', 'vida'],
#  ['disminución',
#   'circulante',
#   'coyuntura',
#   'económico',
#   'equivaler',
#   'cerrar',
#   'llave',
#   'oxígeno',
#   'enfermo'],
#  ['desesperación',
#   'social',
#   'poder',
#   'desbordar',
#   'cualquier',
#   'momento',
#   'producir',
#   'mal',
#   'mayor',
#   'querer',
#   'evitar',
#   'semejante',
#   'política',
#   'económico'],
#  ['escuchar',
#   'usted',
#   'señor',
#   'si',
#   'usted',
#   'desear',
#   'controlar',
#   'inflación',
#   'afectar',
#   'aún',
#   'marginado',
#   'lograr',
#   'posición',
#   'extremista',
#   'fanático',
#   'frenazo',
#   'lastimar',
#   'precisamente',
#   'usted',
#   'pretender',
#   'ayudar',
#   'toda',
#   'justicia'],
#  ['ningún', 'caso', 'variar', 'rumbo'],
#  ['poder', 'haber', 'alzamiento', 'regional'],
#  ['ningún', 'caso', 'variar', 'rumbo'],
#  ['poder', 'haber', 'violencia', 'hambre', 'desesperación'],
#  ['correr', 'peligro', 'injustificado'],
#  ['ningún', 'caso', 'variar', 'rumbo', 'variar', 'rumbo', 'aun', 'final'],
#  ['aun',
#   'final',
#   'ningún',
#   'caso',
#   'variar',
#   'rumbo',
#   'cualquier',
#   'asunto',
#   'relacionar',
#   'autor',
#   'columna',
#   'favor',
#   'enviar',
#   'comunicación',
#   'fax',
#   'editorial',
#   'httpwwwexcelsiorcommxedihtml',
#   'excelsior',
#   'editorial',
#   'lunes',
#   'abril',
#   'volatilidad',
#   'nocivo',
#   'economía',
#   'mexicana',
#   'seguir',
#   'lograr',
#   'sistema',
#   'financiero',
#   'eliminar',
#   'alto',
#   'nivelar',
#   'volatilidad'],
#  ['según',
#   'centro',
#   'estudio',
#   'económico',
#   'sector',
#   'privado',
#   'ceesp',
#   'problema',
#   'sector',
#   'originar',
#   'sólo',
#   'febrero',
#   'salir',
#   'país',
#   'millón',
#   'dólar',
#   'cifra',
#   'equivalente',
#   'casi',
#   'millón',
#   'dólar',
#   'ingresar',
#   'enero',
#   'través',
#   'mercado',
#   'dinero',
#   'bolsa',
#   'valorar'],
#  ['organismo',
#   'destacar',
#   'problema',
#   'eslabón',
#   'débil',
#   'conflictivo',
#   'méxico'],
#  ['sistema',
#   'financiero',
#   'continuar',
#   'arrastrar',
#   'planta',
#   'productivo',
#   'hacia',
#   'contracción',
#   'endeudamiento',
#   'extremo'],
#  ['peor',
#   'aún',
#   'alta',
#   'tasa',
#   'interés',
#   'empujar',
#   'hacia',
#   'insolvencia',
#   'desempleo'],
#  ['hacer',
#   'encarecimiento',
#   'escasez',
#   'crédito',
#   'mayor',
#   'obstáculo',
#   'reactivación',
#   'desarrollo',
#   'país'],
#  ['sentido',
#   'estimación',
#   'ceesp',
#   'advertir',
#   'horizonte',
#   'económico',
#   'propicio',
#   'salir',
#   'crisis'],
#  ['dato',
#   'pronosticar',
#   'después',
#   'abril',
#   'tasa',
#   'interés',
#   'reanudar',
#   'tendencia',
#   'baja'],
#  ['fenómeno',
#   'ir',
#   'traducir',
#   'forzosamente',
#   'retraso',
#   'tan',
#   'anunciar',
#   'repunte',
#   'económico'],
#  ['además',
#   'reconocer',
#   'si',
#   'bien',
#   'valor',
#   'real',
#   'producto',
#   'interno',
#   'bruto',
#   'igualar',
#   'nivel',
#   'dentro',
#   'par',
#   'año',
#   'inversión',
#   'consumo',
#   'privado',
#   'requerir',
#   'periodo',
#   'prolongado',
#   'recuperar'],
#  ['lamentable',
#   'todavía',
#   'altura',
#   'país',
#   'lograr',
#   'abatir',
#   'desequilibrios',
#   'estructural',
#   'economía',
#   'ello',
#   'crecer',
#   'peligro',
#   'grave',
#   'crisis',
#   'social'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxedihtml',
#   'excelsior',
#   'editorial',
#   'lunes',
#   'abril',
#   'larios',
#   'necesario',
#   'devaluar',
#   'considerar',
#   'presidente',
#   'consejo',
#   'coordinador',
#   'empresarial',
#   'héctor',
#   'larios',
#   'santillán',
#   'reducción',
#   'mitad',
#   'servicio',
#   'deuda',
#   'externo',
#   'año',
#   'permitir',
#   'empresa',
#   'disponer',
#   'mayor',
#   'recurso',
#   'económico',
#   'invertir'],
#  ['punto',
#   'vista',
#   'poder',
#   'resultar',
#   'acertado',
#   'versar',
#   'empresa',
#   'invertir'],
#  ['ahora',
#   'sólo',
#   'decir',
#   'ir',
#   'disponer',
#   'mayor',
#   'recurso',
#   'si',
#   'llegar',
#   'conseguir',
#   'empresario',
#   'temer',
#   'mismo',
#   'gobierno',
#   'reprochar',
#   'poner',
#   'circular',
#   'dinero'],
#  ['máxime',
#   'aconsejable',
#   'sobrevaluación',
#   'peso',
#   'devaluación',
#   'menos',
#   'lento',
#   'imponer'],
#  ['larios',
#   'estima',
#   'debe',
#   'hacer',
#   'corregir',
#   'cifra',
#   'balanza',
#   'comercial',
#   'calcular',
#   'segundo',
#   'semestre',
#   'año',
#   'paridad',
#   'pesodólar',
#   'pasar',
#   'o',
#   'unidad'],
#  ['sector',
#   'empresarial',
#   'pendiente',
#   'preferir',
#   'conservar',
#   'dólar',
#   'invertir',
#   'peso',
#   'nueva',
#   'empresa'],
#  ['además',
#   'sector',
#   'caer',
#   'especulación',
#   'mismo',
#   'gobierno',
#   'pequeño',
#   'ahorrador',
#   'saber',
#   'hacer'],
#  ['persistir', 'desconfianza'],
#  ['mientras', 'generar', 'nueva', 'fuente', 'empleo'],
#  ['cce',
#   'prever',
#   'año',
#   'producto',
#   'interno',
#   'bruto',
#   'elevar',
#   'inflación',
#   'aproximadamente',
#   'mitad',
#   'respecto',
#   'año',
#   'anterior'],
#  ['ojalá',
#   'cumplir',
#   'pues',
#   'ver',
#   'cómo',
#   'aumentar',
#   'carencia',
#   'pueblo',
#   'crecer',
#   'pobreza',
#   'llegar',
#   'situación',
#   'crítica'],
#  ['deber', 'pesimista', 'tampoco', 'engañar', 'cosa', 'ir', 'mejor'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxedihtml',
#   'excelsior',
#   'editorial',
#   'lunes',
#   'abril',
#   'regañar',
#   'episcopal',
#   'caso',
#   'bueno',
#   'cristiano',
#   'semana',
#   'santa',
#   'mejor',
#   'decir',
#   'deber',
#   'motivo',
#   'honda',
#   'reflexión',
#   'sentido',
#   'crucifixión',
#   'muerte',
#   'jesús',
#   'pretexto',
#   'holganza',
#   'exceso',
#   'toda',
#   'índole'],
#  ['partir',
#   'ayer',
#   'domingo',
#   'ramo',
#   'ojalá',
#   'prevalecer',
#   'humildad',
#   'virtud',
#   'lamentablemente',
#   'olvidar'],
#  ['sentido',
#   'arzobispo',
#   'méxico',
#   'pedir',
#   'político',
#   'empresario',
#   'líder',
#   'social',
#   'mexicano',
#   'deber',
#   'decir',
#   'mensaje',
#   'aunque',
#   'mayoría',
#   'poder',
#   'atender',
#   'dejar',
#   'lado',
#   'ostentación',
#   'prepotencia',
#   'lujo',
#   'innecesario',
#   'ofender',
#   'miseria',
#   'agobiar',
#   'ciento',
#   'miles',
#   'familia'],
#  ['arzobispo',
#   'norberto',
#   'rivera',
#   'carrera',
#   'secundar',
#   'obispo',
#   'felipe',
#   'arizmendi',
#   'javier',
#   'lozano',
#   'aprovechar',
#   'oportunidad',
#   'atacar',
#   'gobierno',
#   'hoy',
#   'moda',
#   'hacer',
#   'empresario',
#   'hacer',
#   'apoyar',
#   'tono',
#   'impropio',
#   'decir',
#   'sociedad',
#   'deber',
#   'lavar',
#   'mano',
#   'tomar',
#   'decisión',
#   'perversa',
#   'débiles',
#   'lesionar',
#   'realidad',
#   'millón',
#   'pobre',
#   'hambriento',
#   'viven',
#   'largo',
#   'territorio',
#   'nacional'],
#  ['prelado',
#   'decir',
#   'deber',
#   'decir',
#   'gobierno',
#   'pues',
#   'sociedad',
#   'forma',
#   'parte',
#   'aquél'],
#  ['hecho',
#   'aclaración',
#   'caber',
#   'preguntar',
#   'arzobispo',
#   'decisión',
#   'perversa',
#   'poder',
#   'tomar',
#   'tomar',
#   'gobierno',
#   'sociedad',
#   'perjuicio',
#   'pobre'],
#  ['querer', 'decir', 'señalar', 'autoridad', 'deber', 'lavar', 'mano'],
#  ['ahora',
#   'moda',
#   'clérigo',
#   'criticar',
#   'poder',
#   'público',
#   'menos',
#   'debe',
#   'pedir',
#   'precisión',
#   'acusación'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxedihtml',
#   'excelsior',
#   'editorial',
#   'lunes',
#   'abril',
#   'desalojos',
#   'violencia',
#   'proseguir',
#   'chiapas',
#   'violencia',
#   'desalojos',
#   'invasión',
#   'tierra',
#   'abuso',
#   'campesinado'],
#  ['terminar',
#   'acuerdo',
#   'agrario',
#   'dotación',
#   'tierra',
#   'régimen',
#   'perder',
#   'herramienta',
#   'control'],
#  ['último',
#   'dos',
#   'año',
#   'calcular',
#   'gobierno',
#   'estatal',
#   'destinar',
#   'debido',
#   'levantamiento',
#   'ezln',
#   'millón',
#   'peso',
#   'compra',
#   'tierra',
#   'adjudicar',
#   'organización',
#   'campesina',
#   'apegar',
#   'gobierno'],
#  ['detectar',
#   'mucha',
#   'irregularidad',
#   'aplicación',
#   'política',
#   'advertir',
#   'uso',
#   'mano',
#   'durar',
#   'tratar',
#   'apoderar',
#   'pedazo',
#   'tierra',
#   'poder',
#   'vivir'],
#  ['problema',
#   'tierra',
#   'terminar',
#   'mientras',
#   'aplicar',
#   'adecuadamente',
#   'justa',
#   'distribución',
#   'campo',
#   'mira',
#   'riqueza',
#   'producto',
#   'cultivo',
#   'equitativamente',
#   'distribuir'],
#  ['asignación',
#   'fondo',
#   'indemnizaciones',
#   'mal',
#   'controlar',
#   'convertir',
#   'recurso',
#   'enriquecimiento',
#   'ilegal',
#   'funcionario'],
#  ['negocio', 'surgir', 'socaire', 'subvencionar'],
#  ['pagar', 'tierra'],
#  ['dar', 'muestra', 'mansedumbre', 'política', 'recibir', 'terreno'],
#  ['peor', 'represión', 'brutal', 'seguir', 'aumentar', 'lista', 'crimen'],
#  ['enfrentamiento',
#   'impedir',
#   'adecuado',
#   'conciliación',
#   'interesar',
#   'diálogo',
#   'fructífero',
#   'establecer',
#   'firmemente',
#   'sistema',
#   'favorecer',
#   'sufrido',
#   'indígena'],
#  ['respetar',
#   'propietario',
#   'hacienda',
#   'respeto',
#   'merecer',
#   'hambre',
#   'desventurado'],
#  ['editorial',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxexehtml',
#   'excelsior',
#   'ciudad',
#   'lunes',
#   'abril',
#   'salir',
#   'país',
#   'millón',
#   'dls',
#   'febrero',
#   'ceesp',
#   'significar',
#   'casi',
#   'captar',
#   'enero',
#   'volatilidad',
#   'desequilibrios',
#   'financiero',
#   'extender',
#   'trimestre',
#   'después',
#   'abril',
#   'reanudar',
#   'tasa',
#   'interés',
#   'tendencia',
#   'baja',
#   'prever',
#   'apenas',
#   'valor',
#   'real',
#   'pib',
#   'igualar',
#   'nivel',
#   'lograr',
#   'embargo',
#   'inversión',
#   'consumo',
#   'privado',
#   'tardar',
#   'tiempo',
#   'recuperar',
#   'abatir',
#   'inflación',
#   'inducir',
#   'comportamiento',
#   'congruente',
#   'tipo',
#   'cambio',
#   'urgir',
#   'fortalecer',
#   'actividad',
#   'productivo',
#   'gasto',
#   'poder',
#   'afectar',
#   'macroeconomía',
#   'resulta',
#   'pequeña',
#   'influencia',
#   'ejercer',
#   'aplicación',
#   'presuponer',
#   'público',
#   'afirmar',
#   'pedir',
#   'reducir',
#   'carga',
#   'fiscal',
#   'fomento',
#   'industrial',
#   'mayor',
#   'impulso',
#   'exportación',
#   'alberto',
#   'navarrete',
#   'volatilidad',
#   'desequilibrios',
#   'financiero',
#   'primer',
#   'trimestre',
#   'año',
#   'originar',
#   'sólo',
#   'febrero',
#   'salir',
#   'país',
#   'millón',
#   'dólar',
#   'cifra',
#   'equivaler',
#   'casi',
#   'ciento',
#   'millón',
#   'dólar',
#   'ingresar',
#   'enero',
#   'medio',
#   'mercado',
#   'dinero',
#   'bolsa',
#   'valorar',
#   'revelar',
#   'centro',
#   'estudio',
#   'económico',
#   'sector',
#   'privado',
#   'ceesp'],
#  ['reporte',
#   'información',
#   'básico',
#   'toma',
#   'decisión',
#   'documento',
#   'carácter',
#   'restringir',
#   'organismo',
#   'iniciativa',
#   'privado',
#   'señalar',
#   'después',
#   'abril',
#   'tasa',
#   'interesar',
#   'reanudar',
#   'tendencia',
#   'baja'],
#  ['materia',
#   'crecimiento',
#   'económico',
#   'reconocer',
#   'si',
#   'bien',
#   'valor',
#   'real',
#   'producto',
#   'interno',
#   'bruto',
#   'igualar',
#   'nivel',
#   'dentro',
#   'par',
#   'año',
#   'inversión',
#   'consumo',
#   'privado',
#   'requerir',
#   'periodo',
#   'prologado',
#   'recuperar'],
#  ['ello',
#   'virtud',
#   'consumo',
#   'privado',
#   'decrecer',
#   'ciento',
#   'significar',
#   'caída',
#   'vez',
#   'registrar',
#   'pib',
#   'mismo',
#   'año',
#   'comparación',
#   'parte',
#   'inversión',
#   'total',
#   'año',
#   'pasado',
#   'ciento',
#   'baja',
#   'hacer',
#   'situar',
#   'nivelar',
#   'similar',
#   'significar',
#   'retroceso',
#   'cinco',
#   'año'],
#  ['acuerdo',
#   'organismo',
#   'análisis',
#   'empresarial',
#   'perspectiva',
#   'recuperación',
#   'económico',
#   'año',
#   'enfrentar',
#   'problema',
#   'específico'],
#  ['reto', 'actual', 'política', 'económico', 'doble'],
#  ['parte',
#   'decir',
#   'imprescindible',
#   'consolidar',
#   'estabilidad',
#   'principal',
#   'variable',
#   'financiero',
#   'abatir',
#   'presionar',
#   'inflacionarias',
#   'inducir',
#   'comportamiento',
#   'congruente',
#   'tipo',
#   'cambio',
#   'igualmente',
#   'urgente',
#   'actividad',
#   'productivo',
#   'fortalecer',
#   'implicar',
#   'utilizar',
#   'instrumento',
#   'expansión',
#   'gasto',
#   'agregado',
#   'poder',
#   'alterar',
#   'precario',
#   'equilibrio',
#   'macroeconómico'],
#  ['junto',
#   'tema',
#   'rezgo',
#   'aplicación',
#   'gasto',
#   'público',
#   'órgano',
#   'análisis',
#   'cúpula',
#   'empresarial',
#   'desmitificar',
#   'alcance',
#   'mismo',
#   'recurso',
#   'público'],
#  ['si',
#   'bien',
#   'gasto',
#   'público',
#   'poder',
#   'operar',
#   'disparador',
#   'catalizador',
#   'recuperación',
#   'influencia',
#   'desempeño',
#   'general',
#   'economía',
#   'pequeña',
#   'grado',
#   'presuponer',
#   'total',
#   'gobierno',
#   'representar',
#   'equivalente',
#   'cuarta',
#   'parte',
#   'pib'],
#  ['ello',
#   'tomar',
#   'cuenta',
#   'gasto',
#   'federal',
#   'aumentar',
#   'término',
#   'real',
#   'respecto',
#   'realidad',
#   'desembolsar',
#   'íntegro',
#   'representar',
#   'adición',
#   'neto',
#   'expansión',
#   'pib'],
#  ['estimulos',
#   'inversion',
#   'allá',
#   'mecanismo',
#   'cortar',
#   'plazo',
#   'impedir',
#   'nueva',
#   'alteración',
#   'mercado',
#   'financiero',
#   'sector',
#   'privado',
#   'sostener',
#   'verdadero',
#   'recuperación',
#   'económico',
#   'deber',
#   'originar',
#   'resto',
#   'actividad',
#   'económico',
#   'gubernamental',
#   'reclamar',
#   'accionar',
#   'inmediato',
#   'estímulo',
#   'inversión',
#   'consumo',
#   'privado',
#   'disminución',
#   'carga',
#   'fiscal',
#   'política',
#   'industrial',
#   'fomento',
#   'además',
#   'impulso',
#   'indispensable',
#   'exportación'],
#  ['sólo',
#   'manera',
#   'posible',
#   'preparar',
#   'país',
#   'desequilibrios',
#   'nuevamente',
#   'presentar',
#   'principio',
#   'año',
#   'enero',
#   'mercado',
#   'financiero',
#   'arrancar',
#   'perspectiva',
#   'diferente',
#   'permitir',
#   'ingreso',
#   'inversión',
#   'extranjera',
#   'mil',
#   'millón',
#   'dólar',
#   'bolsa',
#   'valorar',
#   'millón',
#   'mercado',
#   'dinero'],
#  ['embargo',
#   'inestabilidad',
#   'febrero',
#   'ahuyentar',
#   'país',
#   'mil',
#   'millón',
#   'sector',
#   'bursátil',
#   'mil',
#   'millón',
#   'dólar',
#   'mercado',
#   'dinero'],
#  ['desafortunadamente',
#   'economía',
#   'mexicana',
#   'requerir',
#   'todavía',
#   'volumen',
#   'significativo',
#   'recurso',
#   'financiero',
#   'nacional',
#   'extranjero',
#   'debido',
#   'ello',
#   'vislumbrar',
#   'disminución',
#   'consistente',
#   'tasa',
#   'interés'],
#  ['primero',
#   'plana',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxexehtml',
#   'excelsior',
#   'ciudad',
#   'lunes',
#   'abril',
#   'interminables',
#   'conflicto',
#   'agrario',
#   'chiapas',
#   'invasión',
#   'desalojos',
#   'muerte',
#   'recurso',
#   'destinar',
#   'regularización',
#   'desviar',
#   'botín',
#   'millón',
#   'funcionario',
#   'particular',
#   'hacienda',
#   'estatal',
#   'compra',
#   'irregular',
#   'predio',
#   'persistir',
#   'inseguridad',
#   'tenencia',
#   'tierra',
#   'andres',
#   'becerril',
#   'enviado',
#   'iii',
#   'último',
#   'san',
#   'cristobal',
#   'casa',
#   'chis',
#   'marzocon',
#   'firma',
#   'acuerdo',
#   'agrario',
#   'declaración',
#   'chiapas',
#   'terminar',
#   'dotación',
#   'tierra',
#   'gobierno',
#   'perder',
#   'herramienta',
#   'control',
#   'fundamental',
#   'posibilitar',
#   'espinoso',
#   'asunto',
#   'agrario',
#   'transformar',
#   'interminable',
#   'movimiento',
#   'político',
#   'severo',
#   'consecuencia',
#   'invasión',
#   'desalojos',
#   'violencia',
#   'muerte'],
#  ['toda',
#   'historia',
#   'malo',
#   'cosecha',
#   'agro',
#   'entidad',
#   'padecer',
#   'sumar',
#   'temporal',
#   'reciente',
#   'compra',
#   'tierra',
#   'desesperado',
#   'intento',
#   'atajar',
#   'caótico',
#   'situación',
#   'sólo',
#   'provocar',
#   'corrupción'],
#  ['calcular',
#   'último',
#   'dos',
#   'año',
#   'gobierno',
#   'estatal',
#   'destinar',
#   'regularización',
#   'agrario',
#   'merced',
#   'levantamiento',
#   'armado',
#   'ezln',
#   'millón',
#   'peso',
#   'equivalente',
#   'quinta',
#   'parte',
#   'deuda',
#   'estatal',
#   'cuales',
#   'millón',
#   'convertir',
#   'botín',
#   'negocio',
#   'redondo',
#   'funcionario',
#   'público',
#   'particular',
#   'seguir',
#   'prófugo',
#   'justicia'],
#  ['rodolfo',
#   'ulloa',
#   'flor',
#   'ex',
#   'secretario',
#   'gobierno',
#   'saúl',
#   'prado',
#   'guerrero',
#   'ex',
#   'coordinador',
#   'desarrollo',
#   'agrario',
#   'mandato',
#   'javier',
#   'lópez',
#   'moreno',
#   'acusado',
#   'actual',
#   'administración',
#   'chiapaneca',
#   'presunto',
#   'responsable',
#   'fraude',
#   'millón',
#   'peso',
#   'compra',
#   'tierra',
#   'existir',
#   'senda',
#   'orden',
#   'aprehensión'],
#  ['millón',
#   'peso',
#   'según',
#   'contraloría',
#   'general',
#   'gobierno',
#   'local',
#   'deber',
#   'servir',
#   'compra',
#   'predio',
#   'mil',
#   'hectárea',
#   'municipio',
#   'total',
#   'tres',
#   'cuatro',
#   'mil',
#   'peso',
#   'hectárea'],
#  ['gobierno', 'considerar', 'uniformidad', 'tabulador', 'precio'],
#  ['manera',
#   'reforma',
#   'agrario',
#   'chiapas',
#   'afirmar',
#   'líder',
#   'campesino',
#   'investigador',
#   'caminar',
#   'exactamente',
#   'sentido',
#   'oponer',
#   'buscar',
#   'principio',
#   'inspirar'],
#  ['lugar',
#   'lograr',
#   'seguridad',
#   'tenencia',
#   'tierra',
#   'entidad',
#   'convertir',
#   'verdadero',
#   'polvorín',
#   'ideal',
#   'justicia',
#   'desarrollo',
#   'libertad',
#   'ir',
#   'cada',
#   'vez',
#   'alejar',
#   'escenario',
#   'agrario',
#   'chiapaneco'],
#  ['asir',
#   'continuar',
#   'colonización',
#   'reforma',
#   'agrario',
#   'integral',
#   'compra',
#   'tierra',
#   'entregar',
#   'dividir',
#   'organización',
#   'recesión',
#   'económico',
#   'superposición',
#   'dotación',
#   'conflicto',
#   'armado',
#   'estructura',
#   'social',
#   'tradicional',
#   'corrupción',
#   'entorpecer',
#   'regularización',
#   'tenencia',
#   'tierra',
#   'chiapas',
#   'ahora',
#   'acuerdo',
#   'agrario',
#   'pasado',
#   'marzo',
#   'pretender',
#   'finiquitar'],
#  ['escenario',
#   'corrupción',
#   'violencia',
#   'suma',
#   'factor',
#   'preponderante',
#   'obstante',
#   'escritor',
#   'eraclio',
#   'zepeda',
#   'secretario',
#   'gobierno',
#   'eduardo',
#   'robledo',
#   'ahora',
#   'julio',
#   'césar',
#   'ruiz',
#   'ferro',
#   'declarar',
#   'palabra',
#   'desalojar',
#   'prohibir',
#   'gobierno',
#   'chiapaneco'],
#  ['particular',
#   'partido',
#   'revolución',
#   'democrático',
#   'prd',
#   'lista',
#   'nombre',
#   'persona',
#   'muerta',
#   'enero',
#   'hecho',
#   'chicomuselo',
#   'fecha',
#   'pichucalco',
#   'nicolás',
#   'ruiz',
#   'decesos',
#   'cuestionar',
#   'agrario',
#   'mayoría'],
#  ['gerardo',
#   'lio',
#   'méndez',
#   'dariel',
#   'resino',
#   'gordillo',
#   'tomás',
#   'velázquez',
#   'hernández',
#   'víctima',
#   'chicomuselo',
#   'francisco',
#   'uribe',
#   'hernández',
#   'fallecer',
#   'estación',
#   'juárez',
#   'enero'],
#  ['decesos',
#   'sumar',
#   'juan',
#   'méndez',
#   'torre',
#   'pedro',
#   'méndez',
#   'torre',
#   'pedro',
#   'méndez',
#   'arco',
#   'marzo',
#   'salto',
#   'agua'],
#  ['tumbalá',
#   'mismo',
#   'mes',
#   'morir',
#   'sebastián',
#   'peña',
#   'díaz',
#   'sebastián',
#   'arco',
#   'guzmán',
#   'juan',
#   'lópez',
#   'jiménez'],
#  ['sólo',
#   'tres',
#   'día',
#   'después',
#   'venustiano',
#   'carranza',
#   'caer',
#   'israel',
#   'pérez',
#   'gonzález',
#   'manuel',
#   'díaz',
#   'vázquez'],
#  ['abril',
#   'pasado',
#   'fallecer',
#   'florentino',
#   'velasco',
#   'alfaro',
#   'municipio',
#   'margarita',
#   'junio',
#   'tila',
#   'reportó',
#   'muerte',
#   'héctor',
#   'pérez',
#   'torre'],
#  ['sabanilla',
#   'julio',
#   'francisco',
#   'alvarez',
#   'gutiérrez',
#   'septiembre',
#   'tila',
#   'volver',
#   'escenario',
#   'violencia',
#   'fallecer',
#   'nicolás',
#   'lópez',
#   'lópez',
#   'nicolás',
#   'lópez',
#   'ramírez',
#   'pascual',
#   'lópez',
#   'torre',
#   'rogelio',
#   'jiménez',
#   'lópez'],
#  ['angel',
#   'albino',
#   'corzo',
#   'septiembre',
#   'octubre',
#   'reportó',
#   'muerte',
#   'antelmo',
#   'roblero',
#   'roblero',
#   'higinio',
#   'sánchez',
#   'rafael',
#   'culebro',
#   'porfirio',
#   'vázquez',
#   'vázquez'],
#  ['villa',
#   'corzo',
#   'octubre',
#   'morir',
#   'nemias',
#   'gómez',
#   'mismo',
#   'día',
#   'angel',
#   'albino',
#   'corzo',
#   'warlain',
#   'hernández',
#   'velázquez'],
#  ['reyes',
#   'penagos',
#   'martínez',
#   'mismo',
#   'municipio',
#   'fallecer',
#   'diciembre',
#   'último',
#   'víctima',
#   'desalojos',
#   'agrario',
#   'seis',
#   'pichucalco',
#   'marzo',
#   'sebastián',
#   'díaz',
#   'mondragón',
#   'héctor',
#   'alvarado',
#   'molina',
# ...
#   'rigor',
#   'actuar',
#   'decisivamente',
#   'encontrar',
#   'mercadeo',
#   'sospechoso',
#   'referir',
#   'director',
#   'ftc'],
#  ['técnica', 'sucio', 'destruir', 'competencia'],
#  ['iomega',
#   'fabricante',
#   'disco',
#   'removibles',
#   'alta',
#   'capacidad',
#   'objeto',
#   'controversia',
#   'foro',
#   'discusión',
#   'america',
#   'online'],
#  ['oficial',
#   'iomega',
#   'levantar',
#   'queja',
#   'acercar',
#   'anuncio',
#   'contener',
#   'información',
#   'falso',
#   'hacer',
#   'costo',
#   'accionar',
#   'bursátil',
#   'volver',
#   'volátil'],
#  ['citar',
#   'corresponsal',
#   'preocupar',
#   'manera',
#   'servicio',
#   'línea',
#   'poder',
#   'empleado',
#   'elevar',
#   'disminuir',
#   'accionar',
#   'manera',
#   'artificial',
#   'través',
#   'desinformación'],
#  ['problema',
#   'consistir',
#   'usar',
#   'nombre',
#   'pantalla',
#   'posible',
#   'saber',
#   'si',
#   'distribuir',
#   'información',
#   'poseer',
#   'doctorado',
#   'saber',
#   'habla',
#   'simplemente',
#   'especulador'],
#  ['información', 'poder'],
#  ['necesitar',
#   'saber',
#   'lector',
#   'registro',
#   'criminal',
#   'propiedad',
#   'público',
#   'número',
#   'registro',
#   'vehículo',
#   'motor',
#   'verificación',
#   'educación',
#   'enorme',
#   'etcétera'],
#  ['americom',
#   'telnetamericom',
#   'empresa',
#   'dedicar',
#   'vender',
#   'información',
#   'contenido',
#   'registro',
#   'público'],
#  ['posible',
#   'realizar',
#   'búsqueda',
#   'exhaustivo',
#   'obtener',
#   'resultado',
#   'minuto'],
#  ['disponible',
#   'momento',
#   'sólo',
#   'unido',
#   'vital',
#   'importancia',
#   'empresario',
#   'reportes',
#   'bancarrota',
#   'crédito',
#   'hipoteca',
#   'investigador',
#   'privado',
#   'registro',
#   'criminal',
#   'detención',
#   'ingreso',
#   'público',
#   'general',
#   'búsqueda',
#   'nombre',
#   'calle',
#   'número',
#   'telefónico'],
#  ['vender',
#   'servicio',
#   'búsqueda',
#   'consulta',
#   'dicha',
#   'información',
#   'último',
#   'encontrar',
#   'dominio',
#   'público',
#   'estricto',
#   'sentido'],
#  ['comentario',
#   'sugerencia',
#   'siempre',
#   'bienvenidos',
#   'email',
#   'julioarrobalabvisunammx',
#   'financiero',
#   'httpwwwexcelsiorcommxforhtml',
#   'excelsior',
#   'foro',
#   'lunes',
#   'abril',
#   'foro',
#   'excelsior',
#   'denunciar',
#   'anomalía',
#   'elección',
#   'jefe',
#   'manzana',
#   'nápoles',
#   'señor',
#   'director',
#   'hacer',
#   'conocimiento',
#   'grande',
#   'anomalía',
#   'irregularidad',
#   'presentar',
#   'colonia',
#   'nápoles',
#   'recién',
#   'pasada',
#   'elección',
#   'jefe',
#   'manzana',
#   'violación',
#   'convocatoria',
#   'dar',
#   'sustento',
#   'proceso',
#   'integración',
#   'organos',
#   'representación',
#   'vecinal',
#   'seguramente',
#   'amparo',
#   'un',
#   'elección',
#   'amañar',
#   'manipular',
#   'tendencioso',
#   'dar',
#   'sustento',
#   'elección',
#   'presidente',
#   'dos',
#   'vocal',
#   'mesa',
#   'directivo',
#   'asociación',
#   'residente',
#   'colonia',
#   'nápoles',
#   'convocar',
#   'autoridad',
#   'delegación',
#   'benito',
#   'juárez',
#   'consejero',
#   'ciudadano',
#   'integrar',
#   'consejo',
#   'ciudadano'],
#  ['colonia',
#   'nápoles',
#   'formar',
#   'manzana',
#   'habitar',
#   'cuales',
#   'elección',
#   'jefe',
#   'manzana',
#   'pesar',
#   'ausentismo',
#   'manifiesto',
#   'impuntualidad',
#   'representante',
#   'autoridad',
#   'asamblea',
#   'elección',
#   'jefe',
#   'manzana'],
#  ['vecino',
#   'organizar',
#   'asamblea',
#   'elegir',
#   'jefe',
#   'manzana',
#   'contar',
#   'presencia',
#   'obligación',
#   'orientar',
#   'conducir',
#   'elección'],
#  ['colonia',
#   'nápoles',
#   'quedar',
#   'elegir',
#   'jefe',
#   'manzana',
#   'representante',
#   'junta',
#   'elección',
#   'ocurrir',
#   'grandioso',
#   'idea',
#   'convocar',
#   'elección',
#   'día',
#   'festivo',
#   'propiciar',
#   'puente',
#   'vacacionalúnico'],
#  ['seguramente',
#   'junta',
#   'elección',
#   'vecinal',
#   'pensar',
#   'elección',
#   'menos',
#   'concurrido',
#   'posible',
#   'según',
#   'manzana',
#   'colonia',
#   'nápoles',
#   'deshabitado',
#   'cambio',
#   'padrón',
#   'electoral',
#   'indicar',
#   'persona',
#   'empadronar'],
#  ['grandísima',
#   'idea',
#   'seleccionar',
#   'edificio',
#   'ahí',
#   'hacer',
#   'votación',
#   'edificio',
#   'lógicamente',
#   'oficina',
#   'cerrado',
#   'persona',
#   'dejar',
#   'votar',
#   'causa',
#   'cuatro',
#   'manzana',
#   'poder',
#   'elegir',
#   'cuatro',
#   'representante'],
#  ['llegar',
#   'empleado',
#   'junta',
#   'negligencia',
#   'conformar',
#   'declarar',
#   'vacante',
#   'elección',
#   'manzana',
#   'alegar',
#   'vecino',
#   'querer',
#   'prestar',
#   'casa',
#   'llevar',
#   'cabo',
#   'elección',
#   'ocurrir',
#   'visitar',
#   'persona',
#   'agotar',
#   'posibilidad',
#   'razón',
#   'dejar',
#   'votar',
#   'persona',
#   'quedar',
#   'nombrar',
#   'jefe',
#   'manzana'],
#  ['si',
#   'consumar',
#   'burla',
#   'vecino',
#   'delegación',
#   'prestar',
#   'mañana',
#   'día',
#   'marzo',
#   'elegir',
#   'mesa',
#   'directivo',
#   'asociación',
#   'residente',
#   'colonia',
#   'nápoles',
#   'colonia',
#   'violar',
#   'abierto',
#   'abierto',
#   'flagrante',
#   'descaradamente',
#   'cláusula',
#   'décima',
#   'séptima',
#   'convocatoria',
#   'elegir',
#   'directivo',
#   'colonia',
#   'pretender',
#   'celebrar',
#   'asamblea',
#   'haber',
#   'convocar',
#   'escribir',
#   'jefe',
#   'manzana',
#   'haber',
#   'determinado',
#   'cinco',
#   'día',
#   'anticipación',
#   'señalar',
#   'convocatoria',
#   'lugar',
#   'hora',
#   'celebrar',
#   'asamblea',
#   'elegir',
#   'mesa',
#   'directivo',
#   'colonia',
#   'colonia',
#   'nápoles'],
#  ['saber',
#   'periódico',
#   'usted',
#   'dirigir',
#   'preocupar',
#   'problema',
#   'afectar',
#   'sociedad',
#   'derivado',
#   'autoridad',
#   'gobernar',
#   'separado',
#   'enviar',
#   'escribir',
#   'presentar',
#   'junta',
#   'elección',
#   'vecinal',
#   'pedir',
#   'posponer',
#   'elección',
#   'mesa',
#   'directivo',
#   'colonia',
#   'lógicamente',
#   'caso',
#   'hacer'],
#  ['atentamente'],
#  ['asociación', 'residente', 'colonia', 'nápoles', 'ac'],
#  ['foro',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxforhtml',
#   'excelsior',
#   'foro',
#   'lunes',
#   'abril',
#   'exponer',
#   'problema',
#   'cuenta',
#   'bancario',
#   'señor',
#   'director',
#   'hacer',
#   'año',
#   'marzo',
#   'enviar',
#   'periódico',
#   'comunicación',
#   'fecha',
#   'recibir',
#   'contestación',
#   'alguna'],
#  ['ahora',
#   'problema',
#   'similar',
#   'ojalá',
#   'posible',
#   'poder',
#   'ayudar',
#   'resolver',
#   'reintegrar',
#   'dinero',
#   'interesar'],
#  ['asunto',
#   'siguiente',
#   'día',
#   'feb',
#   'contar',
#   'cuenta',
#   'maestra',
#   'día',
#   'febrero',
#   'hacer',
#   'un',
#   'compra',
#   'ciudad',
#   'poza',
#   'rica',
#   'pagado',
#   'tarjeta',
#   'activar',
#   'día',
#   'febrero',
#   'sacar',
#   'cajero',
#   'éste',
#   'marcar',
#   'saldo',
#   'día',
#   'febrero',
#   'sacar',
#   'saldo',
#   'imprimir',
#   'día',
#   'febrero',
#   'sacar',
#   'saldo',
#   'imprimir',
#   'día',
#   'febrero',
#   'retirar',
#   'saldo',
#   'imprimir',
#   'día',
#   'febrero',
#   'depositar',
#   'saldo',
#   'imprimir'],
#  ['fin',
#   'completar',
#   'cantidad',
#   'sumar',
#   'gasto',
#   'efectuar',
#   'poza',
#   'rica'],
#  ['mismo',
#   'día',
#   'hablar',
#   'teléfono',
#   'proporcionar',
#   'empleado',
#   'guardar',
#   'comprobante',
#   'verificar',
#   'si',
#   'poder',
#   'nota',
#   'gastar',
#   'poza',
#   'rica'],
#  ['contestar',
#   'señor',
#   'velazco',
#   'decir',
#   'momento',
#   'meter',
#   'importar',
#   'dicho',
#   'vauchers',
#   'computadora',
#   'descontar',
#   'hacer',
#   'sino',
#   'día',
#   'febrero',
#   'comprobante',
#   'cajero',
#   'automático',
#   'día',
#   'febrero',
#   'aparecer',
#   'descuento',
#   'saldo'],
#  ['confianza',
#   'efectuar',
#   'dicho',
#   'descuento',
#   'seguir',
#   'operar',
#   'tarjeta'],
#  ['día', 'febrero', 'llegar', 'abono', 'nómina', 'incrementar', 'saldo'],
#  ['señor',
#   'gerente',
#   'esperar',
#   'introducir',
#   'pago',
#   'si',
#   'según',
#   'persona',
#   'hablar',
#   'día',
#   'tres',
#   'vauchers',
#   'poder',
#   'engañar'],
#  ['además',
#   'día',
#   'día',
#   'febrero',
#   'cuenta',
#   'según',
#   'cuenta',
#   'acabar',
#   'llegar'],
#  ['protestar',
#   'señor',
#   'gerente',
#   'tipo',
#   'accionar',
#   'efectuar',
#   'tarjetahabientes',
#   'además',
#   'señor',
#   'si',
#   'cantidad',
#   'estratosférico',
#   'cheque',
#   'girar',
#   'fondo',
#   'miles',
#   'millón',
#   'peso',
#   'señor',
#   'tarjeta',
#   'cautivo',
#   'además',
#   'si',
#   'tomar',
#   'molestia',
#   'hablar',
#   'teléfono',
#   'tarjeta',
#   'crédito',
#   'requerir',
#   'pago',
#   'acaso',
#   'poder',
#   'hablar',
#   'teléfono',
#   'decir',
#   'avisar',
#   'recordar',
#   'inmediatamente',
#   'proceder',
#   'tarjetahabiente',
#   'caso',
#   'servidor',
#   'pagar',
#   'exorbitante',
#   'cantidad',
#   'faltar'],
#  ['además',
#   'respetable',
#   'señor',
#   'si',
#   'banco',
#   'comercio',
#   'ejército',
#   'empleado',
#   'miles',
#   'equipo',
#   'sofisticado',
#   'cómputo',
#   'cajero',
#   'equivocar',
#   'razón',
#   'persona'],
#  ['lado',
#   'cuenta',
#   'dinero',
#   'manejo',
#   'cuenta',
#   'salario',
#   'jubilado',
#   'cantidad',
#   'dar',
#   'total',
#   'poder',
#   'servir',
#   'comer',
#   'catorcena',
#   'gente',
#   'meter',
#   'problema',
#   'descontar',
#   'dicha',
#   'cantidad'],
#  ['usado',
#   'famoso',
#   'tarjeta',
#   'activar',
#   'hacer',
#   'año',
#   'exactamente',
#   'surgir',
#   'problema',
#   'parecido'],
#  ['considerar',
#   'deber',
#   'devolver',
#   'tarjeta',
#   'destruir',
#   'ir',
#   'dos',
#   'problema',
#   'surgir'],
#  ['acaso',
#   'ahora',
#   'aparte',
#   'cuidar',
#   'asaltante',
#   'cajero',
#   'automático',
#   'proteger',
#   'bandido',
#   'cuello',
#   'blanco'],
#  ['gobierno',
#   'preocupar',
#   'ayudar',
#   'banco',
#   'crédito',
#   'ades',
#   'udis',
#   'etc',
#   'empleado',
#   'banco',
#   'misericordia',
#   'tarjeta',
#   'habientes'],
#  ['anterior',
#   'exponer',
#   'solicitar',
#   'usted',
#   'publicar',
#   'protesta',
#   'reintegrar',
#   'cantidad',
#   'descontar',
#   'elevado',
#   'sobregiro'],
#  ['anexo',
#   'copia',
#   'movimiento',
#   'cuenta',
#   'cheque',
#   'vouchers',
#   'comprobante',
#   'asir',
#   'papel',
#   'anotar',
#   'teléfono',
#   'méxico',
#   'hacer',
#   'aclaración'],
#  ['atentamente'],
#  ['josé',
#   'gabriel',
#   'tovar',
#   'navarro',
#   'calle',
#   'poniente',
#   'casa',
#   'n',
#   'col'],
#  ['unidad', 'habitacional', 'pemex', 'ciudad', 'tula', 'hgo'],
#  ['tel'],
#  ['foro',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxforhtml',
#   'excelsior',
#   'foro',
#   'lunes',
#   'abril',
#   'expresar',
#   'grato',
#   'impresión',
#   'servicio',
#   'imss',
#   'señor',
#   'director',
#   'día',
#   'febrero',
#   'pasado',
#   'ver',
#   'obligado',
#   'ingresar',
#   'hospital',
#   'cardiología',
#   'centro',
#   'médico',
#   'siglo',
#   'xxi',
#   'imss',
#   'crisis',
#   'cardiaca'],
#  ['recibir',
#   'urgencia',
#   'aplicar',
#   'suero',
#   'nueve',
#   'hora',
#   'practicar',
#   'electrocardiograma',
#   'radiografía',
#   'torax',
#   'etc',
#   'etc',
#   'ahí',
#   'trasladar',
#   'cama',
#   'gratamente',
#   'impresionar',
#   'hospital',
#   'asegurar',
#   'primer',
#   'minuto',
#   'llegar',
#   'dar',
#   'alta',
#   'después',
#   'semana',
#   'atender',
#   'mejor',
#   'atender',
#   'hospital',
#   'privado'],
#  ['razón',
#   'dirigir',
#   'foro',
#   'excelsior',
#   'dar',
#   'conocer',
#   'opinión',
#   'público',
#   'afortunado',
#   'contar',
#   'institución',
#   'tan',
#   'alto',
#   'grado',
#   'excelencia',
#   'pesar',
#   'limitación',
#   'económico',
#   'alguien',
#   'decir',
#   'correr',
#   'mucha',
#   'suerte',
#   'nadie',
#   'expresar',
#   'asir',
#   'imss'],
#  ['creer',
#   'creer',
#   'encamado',
#   'pasar',
#   'despedir',
#   'paciente',
#   'dado',
#   'alta',
#   'distinto',
#   'día',
#   'conocer',
#   'ambos',
#   'cirugía',
#   'corazón',
#   'abierto',
#   'frase',
#   'salvar',
#   'vida'],
#  ['lástima', 'publicar', 'hacer', 'dar', 'conocer', 'queja'],
#  ['evidente',
#   'personal',
#   'ala',
#   'tercer',
#   'piso',
#   'cardiología',
#   'cama',
#   'recibir',
#   'capacitación',
#   'permanente',
#   'sindicato',
#   'dirección',
#   'hospital'],
#  ['dar',
#   'corazón',
#   'gracias',
#   'verónica',
#   'recibir',
#   'decir',
#   'ir',
#   'usted',
#   'bueno',
#   'número',
#   'enfermera',
#   'cuyos',
#   'nombre',
#   'saber',
#   'olvidar',
#   'todas',
#   'atender',
#   'brindar',
#   'vocación',
#   'servicio',
#   'calor',
#   'humano'],
#  ['dietoterapeuta',
#   'lucía',
#   'abrego',
#   'raúl',
#   'caballeroso',
#   'conductor',
#   'silla',
#   'rueda'],
#  ['médico',
#   'urgencia',
#   'doctor',
#   'valencia',
#   'piso',
#   'doctor',
#   'luis',
#   'lópez',
#   'vega',
#   'doctora',
#   'limón',
#   'cubículos',
#   'estudio',
#   'ecocardiogramas',
#   'holter',
#   'especial',
#   'señaladamente',
#   'doctor',
#   'rodolfo',
#   'herrera',
#   'franco',
#   'dar',
#   'alta',
#   'recibí',
#   'sobrado',
#   'muestra',
#   'bonhomía',
#   'profesional'],
#  ['mucha', 'muchísimas', 'gracias'],
#  ['agradecer', 'atención', 'señor', 'director'],
#  ['atentamente'],
#  ['mario', 'enrique', 'abitia', 'alonso', 'chabacano', 'col'],
#  ['jardín', 'san', 'mateo', 'naucalpan', 'edo'],
#  ['méxico', 'cp'],
#  ['foro',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxforhtml',
#   'excelsior',
#   'foro',
#   'lunes',
#   'abril',
#   'aferrar',
#   'leyes',
#   'funcionar'],
#  ['señor', 'director', 'tiempo', 'cambiar'],
#  ['costumbre', 'modificar'],
#  ['organización', 'social', 'evolucionar'],
#  ['cultura'],
#  ['tecnología', 'mover', 'hacia', 'plano'],
#  ['aferrar', 'norma', 'leyes', 'funcionar'],
#  ['reforma', 'electoral', 'cuento', 'nunca', 'acabar', 'contar'],
#  ['entonces', 'estr', 'dtura', 'política', 'corrupto', 'seguir', 'vigente'],
#  ['mayoría',
#   'ambiente',
#   'seguir',
#   'plagar',
#   'injusticia',
#   'pobreza',
#   'insalubridad',
#   'ignorancia',
#   'inseguridad'],
#  ['cuanto', 'jauja', 'dinero', 'fácil', 'impunidad'],
#  ['seguir', 'asir', 'corrupto', 'inepto', 'malosos', 'destruir'],
#  ['ignominia', 'valor', 'saber', 'defender', 'patrimonio', 'familia'],
#  ['proponer',
#   'hacer',
#   'cambio',
#   'radical',
#   'méxico',
#   'necesitar',
#   'voto',
#   'abierto',
#   'obligatorio',
#   'secreto',
#   'voluntario',
#   'camino',
#   'real',
#   'democracia'],
#  ['voto',
#   'calidad',
#   'ciudadano',
#   'cuyo',
#   'esfuerzo',
#   'estudio',
#   'experiencia',
#   'dar',
#   'capacidad',
#   'juzgar'],
#  ['poder',
#   'valer',
#   'igual',
#   'voto',
#   'cobarde',
#   'someter',
#   'hombre',
#   'íntegro'],
#  ['poder',
#   'valer',
#   'igual',
#   'voto',
#   'contemplar',
#   'impulsar',
#   'país',
#   'trabajo'],
#  ['propuesta'],
#  ['querer', 'méxico', 'pensar'],
#  ['partido',
#   'oficial',
#   'decir',
#   'poder',
#   'bla',
#   'bla',
#   'bla',
#   'revolución',
#   'derecho',
#   'etc',
#   'etc',
#   'atentamente'],
#  ['julio', 'chargoy', 'martínez', 'acapulco', 'gro'],
#  ['tel'],
#  ['foro',
#   'nota',
#   'siguiente',
#   'httpwwwexcelsiorcommxforhtml',
#   'excelsior',
#   'foro',
#   'lunes',
#   'abril',
#   'comentar',
#   'reflexionar',
#   'caso',
#   'colosio',
#   'señor',
#   'director',
#   'envío',
#   'presente',
#   'fin',
#   'poner',
#   'consideración',
#   'lector',
#   'opinión',
#   'último',
#   'hecho',
#   'político',
#   'social',
#   'aquejar',
#   'ciudad',
#   'permitir',
#   'comunicar',
#   'medio',
#   'foro',
#   'excelsior'],
#  ['escribir',
#   'línea',
#   'noche',
#   'marzo',
#   'después',
#   'haber',
#   'ver',
#   'escuchar',
#   'diverso',
#   'noticiario',
#   'conmemorar',
#   'segundo',
#   'aniversario',
#   'asesinato',
#   'luis',
#   'donaldo',
#   'colosio',
#   'murrieta',
#   'surgir',
#   'rabia',
#   'desaliento',
#   'pertenecer',
#   'país',
#   'tan',
#   'pobre',
#   'justicia'],
#  ['lastimoso',
#   'ver',
#   'cómo',
#   'particular',
#   'referente',
#   'investigación',
#   'crimen',
#   'mencionado',
#   'sólo',
#   'argumento',
#   'confuso',
#   'sentido',
#   'pueblo',
#   'conocer',
#   'aquel',
#   'negro',
#   'secreto',
#   'voz',
#   'nublar',
#   'cualquier',
#   'posibilidad',
#   'respeto',
#   'pueblo',
#   'entero',
#   'sino',
#   'muestra',
#   'fiel',
#   'grave',
#   'situación',
#   'abuso',
#   'gobernante',
#   'funcionario',
#   'utilizar',
#   'puesto',
#   'medio',
#   'enriquecer',
#   'explotar',
#   'degradar',
#   'depender',
#   'alguna',
#   'forma',
#   'ver',
#   'sujeto',
#   'capricho'],
#  ['policía',
#   'esquina',
#   'encumbrar',
#   'político',
#   'abusar',
#   'burlar',
#   'crear',
#   'pueblo',
#   'grande',
#   'anarquía',
#   'sólo',
#   'generar',
#   'creciente',
#   'falta',
#   'respeto',
#   'mismos',
#   'mexicano',
#   'matar',
#   'cada',
#   'vez',
#   'criminal',
#   'sentir',
#   'derecho',
#   'asesinar',
#   'lograr',
#   'tener',
#   'algún',
#   'bien',
#   'fin',
#   'atracar',
#   'pesar',
#   'cada',
#   'vez',
#   'mayor',
#   'delincuencia',
#   'cuerpo',
#   'justicia',
#   'comportar',
#   'tibio',
#   'estático',
#   'dar',
#   'respuesta',
#   'creciente',
#   'demanda'],
#  ['justicia',
#   'cada',
#   'día',
#   'común',
#   'saber',
#   'gente',
#   'público',
#   'formar',
#   'parte',
#   'lista',
#   'víctima',
#   'asesino',
#   'ladrón'],
#  ...]

# %%
def make_vocabulary(text):
    aux_words = list()
    for sent in text:
        for word in sent:
            aux_words.append(word)
    vocabulary = sorted(list(set(aux_words)))
    return vocabulary

# %%
vocabulary = make_vocabulary(preprocessed_text_sents)

# %%
vocabulary
# Out:
# ['abandonar',
#  'abandono',
#  'abarcar',
#  'abarrotar',
#  'abascal',
#  'abasto',
#  'abatir',
#  'abbasso',
#  'abdicar',
#  'aberrantes',
#  'abierto',
#  'abitia',
#  'abono',
#  'abordaje',
#  'aborigen',
#  'abraham',
#  'abrego',
#  'abril',
#  'abrir',
#  'absalón',
#  'absoluto',
#  'absuelto',
#  'absurdamente',
#  'absurdo',
#  'abuelo',
#  'abundante',
#  'abundar',
#  'aburto',
#  'abusar',
#  'abuso',
#  'ac',
#  'acabado',
#  'acabar',
#  'acaparar',
#  'acapulco',
#  'acarreo',
#  'acaso',
#  'accesible',
#  'acceso',
#  'accidente',
#  'accionar',
#  'accionista',
#  'acción',
#  'acelerar',
#  'acento',
#  'acentuado',
#  'aceptabilidad',
#  'aceptar',
#  'acercar',
#  'acero',
#  'acertado',
#  'acierto',
#  'aclaración',
#  'aclarar',
#  'acompañado',
#  'acompañamiento',
#  'acompañar',
#  'aconsejable',
#  'aconsejar',
#  'acontecimiento',
#  'acopio',
#  'acoplamiento',
#  'acoplar',
#  'acorde',
#  'acotar',
#  'acrecentar',
#  'acreditar',
#  'acreedor',
#  'actitud',
#  'activar',
#  'actividad',
#  'activo',
#  'acto',
#  'actor',
#  'actriz',
#  'actuación',
#  'actual',
#  'actualidad',
#  'actualizar',
#  'actualmente',
#  'actuar',
#  'acudir',
#  'acuerdo',
#  'acumulación',
#  'acumular',
#  'acusación',
#  'acusado',
#  'acusar',
#  'adaptar',
#  'adecuadamente',
#  'adecuado',
#  'adelante',
#  'además',
#  'ades',
#  'adeudos',
#  'adicional',
#  'adición',
#  'adjudicar',
#  'adjunta',
#  'adjunto',
#  'administración',
#  'administrador',
#  'administradora',
#  'administrativa',
#  'administrativo',
#  'admirar',
#  'admitir',
#  'adolf',
#  'adolfo',
#  'adoptar',
#  'adornar',
#  'adquirir',
#  'adquisición',
#  'adquisitivo',
#  'adreessen',
#  'adrián',
#  'aducir',
#  'adulto',
#  'advenedizo',
#  'advenimiento',
#  'adverso',
#  'advertencia',
#  'advertir',
#  'advirtiótambién',
#  'aedpch',
#  'aerolíneas',
#  'aeronave',
#  'aeroportuarias',
#  'aeropuerto',
#  'afectado',
#  'afectar',
#  'aferrar',
#  'afiliar',
#  'afirmación',
#  'afirmar',
#  'afore',
#  'afores',
#  'aforismo',
#  'aforo',
#  'afortunado',
#  'afrancisco',
#  'africa',
#  'afrontar',
#  'afuera',
#  'afán',
#  'agencia',
#  'agenda',
#  'agente',
#  'agilidad',
#  'agilizar',
#  'agobiar',
#  'agonía',
#  'agosto',
#  'agotar',
#  'agradecer',
#  'agradezgo',
#  'agrario',
#  'agrarismo',
#  'agraristas',
#  'agraviado',
#  'agreden',
#  'agregado',
#  'agregar',
#  'agremiados',
#  'agricultor',
#  'agro',
#  'agropecuario',
#  'agrupación',
#  'agrupar',
#  'agrícola',
#  'agua',
#  'aguascalientes',
#  'agudización',
#  'agudizar',
#  'agudo',
#  'aguilar',
#  'aguinaco',
#  'aguirre',
#  'agustin',
#  'ahogada',
#  'ahogar',
#  'ahondar',
#  'ahora',
#  'ahorita',
#  'ahorrador',
#  'ahorradores',
#  'ahorro',
#  'ahuyentar',
#  'ahí',
#  'aicm',
#  'aicn',
#  'aire',
#  'aislado',
#  'ajustar',
#  'ajuste',
#  'ala',
#  'alabat',
#  'alarcón',
#  'alargamiento',
#  'alarmante',
#  'alberto',
#  'albino',
#  'albor',
#  'alcalde',
#  'alcance',
#  'alcanzar',
#  'alcayaga',
#  'alcista',
#  'alcohólica',
#  'aldf',
#  'alegar',
#  'alegre',
#  'alejandro',
#  'alejar',
#  'alemania',
#  'alemanista',
#  'alemán',
#  'alentador',
#  'alerta',
#  'alertar',
#  'alfa',
#  'alfaro',
#  'alfonso',
#  'alfredo',
#  'alférez',
#  'alguien',
#  'alguna',
#  'alguno',
#  'algún',
#  'aliado',
#  'alianza',
#  'alice',
#  'alimentación',
#  'alimentario',
#  'alimenticio',
#  'alimento',
#  'allegada',
#  'allende',
#  'alliance',
#  'allora',
#  'allá',
#  'allí',
#  'almacenar',
#  'almoloya',
#  'alonso',
#  'alpha',
#  'alponte',
#  'alpro',
#  'alrededor',
#  'alta',
#  'altamirano',
#  'altar',
#  'altarcito',
#  'alteración',
#  'alterar',
#  'alternar',
#  'altibajos',
#  'alto',
#  'altoparlante',
#  'altura',
#  'altísimo',
#  'alumno',
#  'alvarado',
#  'alvarez',
#  'alvaro',
#  'alza',
#  'alzamiento',
#  'amador',
#  'amargo',
#  'amarra',
#  'amañar',
#  'ambas',
#  'ambicioso',
#  'ambiente',
#  'ambos',
#  'amelia',
#  'amenaza',
#  'america',
#  'americom',
#  'amhym',
#  'amib',
#  'amiga',
#  'amigo',
#  'amor',
#  'amortización',
#  'amparo',
#  'ampliamente',
#  'ampliar',
#  'amplio',
#  'américa',
#  'analista',
#  'analizar',
#  'analítico',
#  'anarquía',
#  'anciano',
#  'andar',
#  'andreessen',
#  'andres',
#  'andrés',
#  'andrómeda',
#  'ane',
#  'anexo',
#  'angel',
#  'angeles',
#  'angloamericanos',
#  'angustia',
#  'angustioso',
#  'anhelar',
#  'anillo',
#  'aniversario',
#  'anomalía',
#  'anotar',
#  'ansioso',
#  'antagónico',
#  'antaño',
#  'antecesor',
#  'antelmo',
#  'anteproyecto',
#  'anterior',
#  'anteriormente',
#  'anticipación',
#  'anticipar',
#  'anticonstitucionales',
#  'antiguo',
#  'antigüita',
#  'antimigratoria',
#  'antipatía',
#  'antonio',
#  'antorcha',
#  'antuna',
#  'anual',
#  'anuencia',
#  'anular',
#  'anunciar',
#  'anuncio',
#  'anáhuac',
#  'análisis',
#  'apacible',
#  'apaciguar',
#  'apapacho',
#  'aparato',
#  'aparecer',
#  'aparentemente',
#  'aparición',
#  'apartado',
#  'apartar',
#  'aparte',
#  'apegar',
#  'apego',
#  'apelación',
#  'apenas',
#  'apertura',
#  'aplicable',
#  'aplicación',
#  'aplicado',
#  'aplicar',
#  'apoderado',
#  'apoderamientos',
#  'apoderar',
#  'aporrear',
#  'aportar',
#  'apostar',
#  'apoteótica',
#  'apoyar',
#  'apoyo',
#  'apple',
#  'applets',
#  'apreciación',
#  'apreciar',
#  'aprehensión',
#  'aprender',
#  'apresar',
#  'apresta',
#  'apresurar',
#  'aprobación',
#  'aprobar',
#  'apropiado',
#  'aprovechada',
#  'aprovechamiento',
#  'aprovechar',
#  'aproximadamente',
#  'aproximado',
#  'aptitud',
#  'apuntar',
#  'aquejar',
#  'aquel',
#  'aquella',
#  'aquello',
#  'aquellos',
#  'aquél',
#  'aquí',
#  'ara',
#  'aragón',
#  'arancel',
#  'arbitral',
#  'arbitrario',
#  'arca',
#  'archivo',
#  'arco',
#  'arder',
#  'ardid',
#  'arena',
#  'argentina',
#  'argumentar',
#  'argumento',
#  'aria',
#  'arizmendi',
#  'arma',
#  'armada',
#  'armado',
#  'armando',
#  'armonía',
#  'armónicamente',
#  'armónico',
#  'arnault',
#  'arqueológico',
#  'arquitecto',
#  'arquitectura',
#  'arrancar',
#  'arrastrar',
#  'arreglo',
#  'arrendadora',
#  'arreola',
#  'arresto',
#  'arriba',
#  'arribar',
#  'arribo',
#  'arrobaexcelsiorcommx',
#  'arrojar',
#  'arropar',
#  'arroyo',
#  'arte',
#  'artificial',
#  'artimaña',
#  'artista',
#  'arturo',
#  'artículo',
#  'arvizu',
#  'arzobispo',
#  'arzú',
#  'asa',
#  'asalariada',
#  'asalariado',
#  'asaltante',
#  'asamblea',
#  'asambleísta',
#  'asambleístas',
#  'ascender',
#  'ascensión',
#  'ascenso',
#  'asegurar',
#  'asentar',
#  'asentir',
#  'asequible',
#  'asesinar',
#  'asesinato',
#  'asesino',
#  'asesorar',
#  'asesoría',
#  'aseverar',
#  'asfixia',
#  'asfixiar',
#  'asignación',
#  'asignar',
#  'asimilar',
#  'asimismo',
#  'asir',
#  'asistencia',
#  'asistencial',
#  'asistente',
#  'asistir',
#  'asociación',
#  'asociar',
#  'aspecto',
#  'aspiración',
#  'aspirar',
#  'astronauta',
#  'astroso',
#  'astucia',
#  'asueto',
#  'asumir',
#  'asunto',
#  'atacar',
#  'atajar',
#  'atar',
#  'atención',
#  'atender',
#  'atentamente',
#  'atentar',
#  'aterrizaje',
#  'aterrizar',
#  'atinadamente',
#  'atinado',
#  'atisbar',
#  'atlantis',
#  'atoyac',
#  'atracar',
#  'atractivo',
#  'atraer',
#  'atraso',
#  'atravesar',
#  'através',
#  'atribución',
#  'audio',
#  'auditar',
#  'auditoria',
#  'auditorias',
#  'auditorio',
#  'auditoría',
#  'augusta',
#  'aumentar',
#  'aumento',
#  'aun',
#  'aunque',
#  'auque',
#  'aurora',
#  'ausentismo',
#  'auspiciar',
#  'australia',
#  'austria',
#  'auto',
#  'autobús',
#  'autoconsumo',
#  'autoinvasiones',
#  'automática',
#  'automáticamente',
#  'automático',
#  'automóvil',
#  'autonomía',
#  'autopista',
#  'autor',
#  'autoridad',
#  'autoritarismo',
#  'autorizar',
#  'autotransporte',
#  'autotransportes',
#  'autrey',
#  'auténtica',
#  'auténtico',
#  'autónomo',
#  'auxiliar',
#  'auxilio',
#  'av',
#  'avalúos',
#  'avance',
#  'avanzar',
#  'avecinan',
#  'avelar',
#  'avenida',
#  'averiguaciones',
#  'averiguar',
#  'aversión',
#  'avila',
#  'avisar',
#  'aviso',
#  'avión',
#  'ayala',
#  'ayer',
#  'ayuda',
#  'ayudar',
#  'ayuno',
#  'azcapotzalco',
#  'azteca',
#  'azul',
#  'azúcar',
#  'aéreo',
#  'añadir',
#  'año',
#  'aún',
#  'bache',
#  'bah',
#  'baile',
#  'baja',
#  'bajar',
#  'bajo',
#  'balance',
#  'balanza',
#  'baldenegro',
#  'balneario',
#  'balón',
#  'banamex',
#  'banc',
#  'banca',
#  'bancario',
#  'bancarrota',
#  'banco',
#  'bancomer',
#  'bandera',
#  'bandido',
#  'bando',
#  'banjidal',
#  'banobras',
#  'banquero',
#  'banqueta',
#  'banrural',
#  'banxico',
#  'baranda',
#  'barato',
#  'barba',
#  'barca',
#  'barco',
#  'barra',
#  'barragán',
#  'barreda',
#  'barrio',
#  'bartola',
#  'basar',
#  'base',
#  'bastante',
#  'bastar',
#  'basura',
#  'baño',
#  'bdem',
#  'beach',
#  'bebida',
#  'beca',
#  'becerril',
#  'bell',
#  'beltrones',
#  'belén',
#  'bendecir',
#  'bendición',
#  'beneficiar',
#  'beneficiario',
#  'beneficios',
#  'benito',
#  'benévolo',
#  'berdejo',
#  'bernal',
#  'besar',
#  'bezanilla',
#  'bianual',
#  'bicicleta',
#  'bien',
#  'bienestar',
#  'bienintencionado',
#  'bienvenidos',
#  'bill',
#  'billete',
#  'bimestre',
#  'biofísicos',
#  'biológico',
#  'bla',
#  'blaha',
#  'blanca',
#  'blanco',
#  'blando',
#  'blanquiazul',
#  'blemas',
#  'bloquear',
#  'bmv',
#  'bobo',
#  'boca',
#  'bodrios',
#  'boeing',
#  'bolita',
#  'bolsa',
#  'bolseros',
#  'bombardear',
#  'bonhomía',
#  'bonos',
#  'boom',
#  'borde',
#  'bordo',
#  'borghese',
#  'borja',
#  'borrego',
#  'bosque',
#  'botín',
#  'bours',
#  'brasil',
#  'braun',
#  'brecha',
#  'bretaña',
#  'brete',
#  'breve',
#  'breves',
#  'brindar',
#  'brito',
#  'británica',
#  'brote',
#  'brusco',
#  'brutal',
#  'bruto',
#  'buena',
#  'bueno',
#  'bulevar',
#  'burla',
#  'burlar',
#  'bursátil',
#  'busca',
#  'buscar',
#  'butírica',
#  'buzonsímbolo',
#  'básicamente',
#  'básico',
#  'búfalo',
#  'búho',
#  'búsqueda',
#  'cabal',
#  'caballero',
#  'caballeroso',
#  'cabalmente',
#  'caber',
#  'cabeza',
#  'cabezal',
#  'cabida',
#  'cabildo',
#  'cabina',
#  'cabo',
#  'cabrera',
#  'cada',
#  'cadena',
#  'caer',
#  'café',
#  'caifás',
#  'cairo',
#  'caj',
#  'cajb',
#  'cajero',
#  'calabozo',
#  'calado',
#  'calcular',
#  'caldaria',
#  'caldera',
#  'calderón',
#  'calidad',
#  'calificación',
#  'calificar',
#  'california',
#  'californianas',
#  'calle',
#  'callejón',
#  'calley',
#  'callista',
#  'calor',
#  'calumnia',
#  'cama',
#  'camacho',
#  'cambiar',
#  'cambiaria',
#  'cambiario',
#  'cambio',
#  'caminar',
#  'camino',
#  'camioneras',
#  'camioneta',
#  'campa',
#  'campamento',
#  'campaña',
#  'campesina',
#  'campesinado',
#  'campesino',
#  'campestre',
#  'campion',
#  'campo',
#  'canacintra',
#  'canaco',
#  'canadiense',
#  'canadá',
#  'canal',
#  'canalizar',
#  'cancelar',
#  'cancino',
#  'cancún',
#  'candado',
#  'candidato',
#  'candidatura',
#  'cano',
#  'cansancio',
#  'cantar',
#  'cantidad',
#  'cantinflas',
#  'canto',
#  'capacidad',
#  'capacitación',
#  'capital',
#  'capitalino',
#  'capitalismo',
#  'capitalización',
#  'capitalizar',
#  'capricho',
#  'captación',
#  'captar',
#  'cara',
#  'caracterizado',
#  'caracterizar',
#  'característica',
#  'carantoña',
#  'cardenismo',
#  'cardenista',
#  'cardiaca',
#  'cardiología',
#  'cardona',
#  'carecer',
#  'carencia',
#  'carga',
#  'cargar',
#  'cargo',
#  'caribe',
#  'carlos',
#  'carne',
#  'caro',
#  'carpio',
#  'carranza',
#  'carrera',
#  'carretera',
#  'carretero',
#  'carruseles',
#  'carso',
#  'carta',
#  'cartera',
#  'cartulina',
#  'carácter',
#  'casa',
#  'casanova',
#  'casar',
#  'casi',
#  'casilla',
#  'caso',
#  'castellano',
#  'castigar',
#  'castigo',
#  'castillo',
#  'catalizador',
#  'catar',
#  'catastrófico',
#  'catorcena',
#  'catálogo',
#  'catástrofe',
#  'católica',
#  'católico',
#  'cauce',
#  'caudillesca',
#  'caudillo',
#  'causa',
#  'causante',
#  'causar',
#  'cautivo',
#  'caída',
#  'caído',
#  'cañaveral',
#  'cañedo',
#  'caótico',
#  'cce',
#  'cdiez',
#  'cdrom',
#  'ceder',
#  'ceesp',
#  'celebración',
#  'celebrar',
#  'cemex',
#  'cen',
#  'cena',
#  'ceniza',
#  'censura',
#  'censurar',
#  'centavo',
#  'centenar',
#  'central',
#  'centro',
#  'centroamericana',
#  'ceoic',
#  'cepal',
#  'cerca',
#  'cercano',
#  'cercanía',
#  'cerda',
#  'cerdo',
#  'ceremonia',
#  'ceremonial',
#  'cero',
#  'cerrado',
#  'cerrar',
#  'certidumbre',
#  'certificación',
#  'cesarman',
#  'cese',
#  'cete',
#  'cfe',
#  'cfrjn',
#  'chabacano',
#  'chacona',
#  'chapa',
#  'chapopote',
#  'chargoy',
#  'charros',
#  'charter',
#  'charters',
#  'cheque',
#  'chiapaneca',
#  'chiapaneco',
#  'chiapas',
#  'chico',
#  'chicomuselo',
#  'chile',
#  'chilton',
#  'china',
#  'chino',
#  'chirinos',
#  'chis',
#  'chiste',
#  'chivo',
#  'chocante',
#  'chofer',
#  'choque',
#  'chovinismo',
#  'churubuscoal',
#  'chávez',
#  'chéquelo',
#  'ciberespacio',
#  'ciberlectores',
#  'ciclo',
#  'cien',
#  'ciencia',
#  'cienfuegos',
#  'ciento',
#  'científica',
#  'científico',
#  'cierne',
#  'cierre',
#  'ciertamente',
#  'cierto',
#  'cifra',
#  'cifrián',
#  'cihmech',
#  'cima',
#  'cimentaciones',
#  'cimentar',
#  'cimiento',
#  'cinco',
#  'cine',
#  'cinematografistas',
#  'cinematográfico',
#  'cinescopios',
#  'cinturón',
#  'cioac',
#  'circuito',
#  'circulación',
#  'circulante',
#  'circular',
#  'circunstancia',
#  'cirugía',
#  'cita',
#  'citadino',
#  'citar',
#  'citroen',
#  'ciudad',
#  'ciudadano',
#  'civil',
#  'civilizado',
#  'clandestino',
#  'clara',
#  'claramente',
#  'claremont',
#  'clark',
#  'claro',
#  'claroscuro',
#  'clase',
#  'clasificación',
#  'clave',
#  'clavícula',
#  'clemencia',
#  'clero',
#  'cliente',
#  'clienteservidor',
#  'clifford',
#  'clima',
#  'clásico',
#  'cláusula',
#  'clérigo',
#  'cna',
#  'cnbv',
#  'cnc',
#  'cniv',
#  'cnpi',
#  'co',
#  'coalcomán',
#  'coalición',
#  'cobarde',
#  'cobertura',
#  'cobrar',
#  'cocoyoc',
#  'coexistir',
#  'coger',
#  'coicidieron',
#  'coincidente',
#  'coincidir',
#  'col',
#  'colaborar',
#  'colbeth',
#  'colchón',
#  'coleccionar',
#  'colección',
#  'colectivo',
#  'colega',
#  'colegiado',
#  'colegiatura',
#  'colgado',
#  'colgar',
#  ...]

# %%
len(vocabulary)
# Out:
# 5471

# %% [markdown]
# ## Entropy and Mutual Information
#
# Once we have completed our preprocessing, it's time to define the functions to find the probability of a certain word appearance in a sentence, the conditional probability that a word appears given another word in the same sentence, and finally the joint probability of two words in the same sentence. Then, with those functions we could be able to calculate entropy and the mutual information between words.

# %%
import numpy as np

# %%
def probability_word(text, word, ocurs = True):
    wordocurs = [sent for sent in text if word in sent]
    if ocurs:
        probability = (len(wordocurs) + 0.5) / (len(text) + 1)
    else:
        probability = 1 - ((len(wordocurs) + 0.5) / (len(text) + 1))
    return probability

def joint_probability(text, word1, word2, ocurs1 = True, ocurs2 = True):
    if ocurs1 and ocurs2:
        word1and2ocurs = [sent for sent in text if word1 in sent and word2 in sent]
        probability = (len(word1and2ocurs) + 0.25) / (len(text) + 1)
    elif ocurs1 and not ocurs2:
        word1andnot2ocurs = [sent for sent in text if word1 in sent and word2 not in sent]
        probability = (len(word1andnot2ocurs) + 0.25) / (len(text) + 1)
    elif not ocurs1 and ocurs2:
        wordnot1and2ocurs = [sent for sent in text if word1 not in sent and word2 in sent]
        probability = (len(wordnot1and2ocurs) + 0.25) / (len(text) + 1)
    elif not ocurs1 and not ocurs2:
        wordnot1andnot2ocurs = [sent for sent in text if word1 not in sent and word2 not in sent]
        probability = (len(wordnot1andnot2ocurs) + 0.25) / (len(text) + 1)
    return probability

def conditional_probability(text, word1, word2, ocurs1 = True, ocurs2 = True):
    probability = 0
    if probability_word(text, word1, ocurs1) != 0:
        probability = joint_probability(text, word1, word2, ocurs1, ocurs2) / probability_word(text, word1, ocurs1)
    return probability
 
def entropy(text, word1, word2):
    states = [True, False]
    sum1 = 0
    for i in states:
        sum2 = 0
        for j in states:
            sum2 = sum2 + (-conditional_probability(text, word1, word2, i, j) * np.log2(conditional_probability(text, word1, word2, i, j)))
        sum1 = sum1 + (probability_word(text, word1, i) * sum2)
    return sum1

def get_entropies(text, word1, vocabulary):
    entropies = dict()
    for w in vocabulary:
        entropies[w] = entropy(text, word1, w)
    entropies = (sorted(entropies.items(), key = lambda item: item[1], reverse = True))
    with open('./entropies/entropies_of_words_with_' + word1 + '.txt', 'w', encoding = 'utf-8') as f:
        for item in entropies:
            f.write(str(item) + '\n')
            
def mutual_information(text, word1, word2):
    states = [True, False]
    sum1 = 0
    for i in states:
        sum2 = 0
        for j in states:
            sum2 = joint_probability(text, word1, word2, i, j) * np.log2(joint_probability(text, word1, word2, i, j) / (probability_word(text, word1, i) * probability_word(text, word2, j)))
            sum1 = sum1 + sum2
    return sum1

def get_mutual_informations(text, word1, vocabulary):
    mut_infs = dict()
    for w in vocabulary:
        mut_infs[w] = mutual_information(text, word1, w)
    mut_infs = (sorted(mut_infs.items(), key = lambda item: item[1], reverse = True))
    with open('./mutual_informations/mutual_information_of_words_with_' + word1 + '.txt', 'w', encoding = 'utf-8') as f:
        for item in mut_infs:
            f.write(str(item) + '\n')

# %% [markdown]
# #### Entropy estimations from preprocessed text with sentence tokens

# %%
w = "empresa"
try:
    get_entropies(preprocessed_text_sents, w, vocabulary)
    print('Entropy estimations of \033[1m' + w + '\033[0m completed\n')
except Exception as e:
    print('An error has occured: ' + e + ' in word ' + w)
# Out:
# Entropy estimations of empresa completed

# %% [markdown]
# #### Mutual information estimations from preprocessed text with sentence tokens

# %%
w = "empresa"
try:
    get_mutual_informations(preprocessed_text_sents, w, vocabulary)
    print('MI estimations of \033[1m' + w + '\033[0m completed\n')
except Exception as e:
    print('An error has occured: ' + e + ' in word ' + w)
# Out:
# MI estimations of empresa completed
