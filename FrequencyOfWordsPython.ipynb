# %%
#JuarezRamirezLuis
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dof.gob.mx/nota_detalle.php?codigo=5687777&fecha=04/05/2023#gsc.tab=0'
fr = []
a=requests.get(url, verify=False).text
soup = BeautifulSoup(a, 'html.parser')
clean_text = soup.get_text()
clean_text = clean_text.lower()

def count(elements):
	if elements[-1] == '.':
		elements = elements[0:len(elements) - 1]
	if elements in dictionary:
		dictionary[elements] += 1
	else:
		dictionary.update({elements: 1})

Sentence = clean_text
dictionary = {}
lst = Sentence.split()
for elements in lst:
	count(elements)

for allKeys in dictionary:
	print ("Frecuencia de ", allKeys, end = " ")
	print (":", end = " ")
	print (dictionary[allKeys], end = " ")
	print()
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.dof.gob.mx'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Frecuencia de  dof : 4
# Frecuencia de  - : 1
# Frecuencia de  diario : 5
# Frecuencia de  oficial : 5
# Frecuencia de  de : 93
# Frecuencia de  la : 75
# Frecuencia de  federación : 3
# Frecuencia de  su : 5
# Frecuencia de  navagedor : 1
# Frecuencia de  no : 7
# Frecuencia de  soporta : 1
# Frecuencia de  javascript! : 1
# Frecuencia de  usuario : 2
# Frecuencia de  clave : 1
# Frecuencia de  entrar : 1
# Frecuencia de  ¿olvidó : 2
# Frecuencia de  clave? : 1
# Frecuencia de  usuario? : 1
# Frecuencia de  inicio : 2
# Frecuencia de  | : 5
# Frecuencia de  directorio : 1
# Frecuencia de  contacto : 1
# Frecuencia de  mapa : 1
# Frecuencia de  del : 16
# Frecuencia de  sitio : 1
# Frecuencia de  ayuda : 1
# Frecuencia de   : 1
# Frecuencia de  busqueda : 1
# Frecuencia de  ejemplar : 1
# Frecuencia de  hoy : 1
# Frecuencia de  trámites : 1
# Frecuencia de  servicios : 6
# Frecuencia de  leyes : 1
# Frecuencia de  y : 29
# Frecuencia de  reglamentos : 1
# Frecuencia de  preguntas : 1
# Frecuencia de  frecuentes : 1
# Frecuencia de  publicación : 2
# Frecuencia de  documentos : 2
# Frecuencia de  adquisición : 1
# Frecuencia de  ejemplares : 2
# Frecuencia de  cotizador : 1
# Frecuencia de  publicaciones : 1
# Frecuencia de  consulta : 2
# Frecuencia de  existencias : 1
# Frecuencia de  solicitud : 1
# Frecuencia de  en : 19
# Frecuencia de  forma : 1
# Frecuencia de  electrónica : 1
# Frecuencia de  dof: : 1
# Frecuencia de  04/05/2023 : 1
# Frecuencia de  circular : 4
# Frecuencia de  por : 8
# Frecuencia de  que : 20
# Frecuencia de  se : 8
# Frecuencia de  comunica : 2
# Frecuencia de  a : 26
# Frecuencia de  las : 9
# Frecuencia de  dependencias : 4
# Frecuencia de  entidades : 8
# Frecuencia de  administración : 4
# Frecuencia de  pública : 5
# Frecuencia de  federal, : 4
# Frecuencia de  fiscalía : 4
# Frecuencia de  general : 5
# Frecuencia de  república, : 4
# Frecuencia de  así : 4
# Frecuencia de  como : 5
# Frecuencia de  los : 9
# Frecuencia de  gobiernos : 4
# Frecuencia de  federativas, : 4
# Frecuencia de  municipios : 4
# Frecuencia de  alcaldías : 4
# Frecuencia de  ciudad : 7
# Frecuencia de  méxico, : 4
# Frecuencia de  deberán : 2
# Frecuencia de  abstenerse : 1
# Frecuencia de  aceptar : 1
# Frecuencia de  propuestas : 2
# Frecuencia de  o : 6
# Frecuencia de  celebrar : 2
# Frecuencia de  contratos : 2
# Frecuencia de  con : 9
# Frecuencia de  empresa : 4
# Frecuencia de  dronit, : 1
# Frecuencia de  s : 2
# Frecuencia de  r.l : 2
# Frecuencia de  c.v : 1
# Frecuencia de  persona : 4
# Frecuencia de  física : 4
# Frecuencia de  representó : 3
# Frecuencia de  legalmente, : 2
# Frecuencia de  ciudadana : 4
# Frecuencia de  diana : 4
# Frecuencia de  carina : 4
# Frecuencia de  ortega : 4
# Frecuencia de  rosa, : 4
# Frecuencia de  incluso : 2
# Frecuencia de  cuando : 3
# Frecuencia de  este : 1
# Frecuencia de  último : 1
# Frecuencia de  pretenda : 2
# Frecuencia de  representar : 2
# Frecuencia de  empresas : 2
# Frecuencia de  diversas : 2
# Frecuencia de  sancionada : 2
# Frecuencia de  al : 3
# Frecuencia de  margen : 1
# Frecuencia de  un : 1
# Frecuencia de  sello : 1
# Frecuencia de  el : 16
# Frecuencia de  escudo : 1
# Frecuencia de  nacional, : 2
# Frecuencia de  dice: : 1
# Frecuencia de  estados : 2
# Frecuencia de  unidos : 2
# Frecuencia de  mexicanos.- : 1
# Frecuencia de  secretaría : 4
# Frecuencia de  función : 2
# Frecuencia de  pública.- : 1
# Frecuencia de  órgano : 2
# Frecuencia de  interno : 2
# Frecuencia de  control : 2
# Frecuencia de  defensa : 2
# Frecuencia de  nacional.- : 1
# Frecuencia de  área : 2
# Frecuencia de  responsabilidades.- : 1
# Frecuencia de  expediente : 1
# Frecuencia de  014/pas/2021 : 1
# Frecuencia de  ar07- : 1
# Frecuencia de  10/2023 : 1
# Frecuencia de  oficiales : 1
# Frecuencia de  mayores : 1
# Frecuencia de  equivalentes : 1
# Frecuencia de  méxico : 1
# Frecuencia de  presentes : 1
# Frecuencia de  fundamento : 1
# Frecuencia de  artículos : 1
# Frecuencia de  14, : 1
# Frecuencia de  16 : 1
# Frecuencia de  134 : 1
# Frecuencia de  constitución : 1
# Frecuencia de  política : 1
# Frecuencia de  mexicanos; : 1
# Frecuencia de  1, : 2
# Frecuencia de  2, : 3
# Frecuencia de  29, : 1
# Frecuencia de  37, : 1
# Frecuencia de  45 : 1
# Frecuencia de  penúltimo : 1
# Frecuencia de  párrafo, : 1
# Frecuencia de  46, : 1
# Frecuencia de  59 : 1
# Frecuencia de  60 : 2
# Frecuencia de  fracción : 8
# Frecuencia de  iii : 2
# Frecuencia de  ley : 4
# Frecuencia de  adquisiciones, : 4
# Frecuencia de  arrendamientos : 4
# Frecuencia de  sector : 3
# Frecuencia de  público; : 1
# Frecuencia de  111, : 1
# Frecuencia de  112, : 1
# Frecuencia de  113, : 1
# Frecuencia de  114 : 1
# Frecuencia de  ii, : 1
# Frecuencia de  115 : 1
# Frecuencia de  118 : 1
# Frecuencia de  reglamento; : 1
# Frecuencia de  8 : 2
# Frecuencia de  9 : 1
# Frecuencia de  primer : 1
# Frecuencia de  párrafo : 2
# Frecuencia de  federal : 1
# Frecuencia de  procedimiento : 3
# Frecuencia de  administrativo, : 1
# Frecuencia de  aplicación : 2
# Frecuencia de  supletoria : 1
# Frecuencia de  y; : 1
# Frecuencia de  3, : 2
# Frecuencia de  6 : 1
# Frecuencia de  iii, : 1
# Frecuencia de  letra : 1
# Frecuencia de  b, : 1
# Frecuencia de  numeral : 2
# Frecuencia de  x, : 1
# Frecuencia de  12 : 2
# Frecuencia de  xii, : 1
# Frecuencia de  37 : 1
# Frecuencia de  xvi : 1
# Frecuencia de  xxvii, : 1
# Frecuencia de  38 : 1
# Frecuencia de  19, : 1
# Frecuencia de  40, : 1
# Frecuencia de  92 : 1
# Frecuencia de  ii : 1
# Frecuencia de  99 : 1
# Frecuencia de  reglamento : 3
# Frecuencia de  interior : 1
# Frecuencia de  vigente : 2
# Frecuencia de  fecha : 3
# Frecuencia de  respectivo; : 1
# Frecuencia de  cumplimiento : 1
# Frecuencia de  lo : 4
# Frecuencia de  ordenado : 1
# Frecuencia de  cuarto : 1
# Frecuencia de  resolutivo : 1
# Frecuencia de  resolución : 2
# Frecuencia de  dictada : 1
# Frecuencia de  dentro : 1
# Frecuencia de  administrativo : 1
# Frecuencia de  sanción : 1
# Frecuencia de  licitantes : 1
# Frecuencia de  proveedores : 1
# Frecuencia de  número : 1
# Frecuencia de  014/pas/2021, : 1
# Frecuencia de  mediante : 1
# Frecuencia de  cual : 1
# Frecuencia de  le : 2
# Frecuencia de  impuso : 1
# Frecuencia de  "dronit, : 1
# Frecuencia de  c.v." : 1
# Frecuencia de  una : 3
# Frecuencia de  multa, : 1
# Frecuencia de  cantidad : 1
# Frecuencia de  $217,729.74 : 1
# Frecuencia de  (doscientos : 1
# Frecuencia de  diecisiete : 1
# Frecuencia de  mil : 1
# Frecuencia de  setecientos : 1
# Frecuencia de  veintinueve : 1
# Frecuencia de  pesos : 1
# Frecuencia de  74/100 : 1
# Frecuencia de  m.n.), : 1
# Frecuencia de  equivalente : 1
# Frecuencia de  57 : 1
# Frecuencia de  veces : 1
# Frecuencia de  salario : 1
# Frecuencia de  mínimo : 1
# Frecuencia de  méxico), : 1
# Frecuencia de  como, : 1
# Frecuencia de  inhabilitación, : 2
# Frecuencia de  término : 1
# Frecuencia de  tres : 1
# Frecuencia de  meses, : 1
# Frecuencia de  tanto : 1
# Frecuencia de  referida : 2
# Frecuencia de  mencionada : 1
# Frecuencia de  representó, : 1
# Frecuencia de  para : 2
# Frecuencia de  presentar : 1
# Frecuencia de  sí : 2
# Frecuencia de  interpósita : 1
# Frecuencia de  persona, : 1
# Frecuencia de  contrato : 1
# Frecuencia de  alguno : 1
# Frecuencia de  sus : 1
# Frecuencia de  utilicen : 1
# Frecuencia de  total : 1
# Frecuencia de  parcialmente : 1
# Frecuencia de  recursos : 1
# Frecuencia de  públicos : 1
# Frecuencia de  materia : 1
# Frecuencia de  bienes : 1
# Frecuencia de  prestación : 1
# Frecuencia de  cualquier : 1
# Frecuencia de  naturaleza : 1
# Frecuencia de  relacionados : 1
# Frecuencia de  actividades : 1
# Frecuencia de  sustantivas : 1
# Frecuencia de  carácter : 1
# Frecuencia de  público, : 1
# Frecuencia de  sancionada, : 1
# Frecuencia de  plazo : 3
# Frecuencia de  comenzará : 1
# Frecuencia de  contarse : 1
# Frecuencia de  partir : 1
# Frecuencia de  día : 2
# Frecuencia de  siguiente : 1
# Frecuencia de  publique : 1
# Frecuencia de  presente : 4
# Frecuencia de  concepto, : 1
# Frecuencia de  que, : 2
# Frecuencia de  atendiendo : 1
# Frecuencia de  señalado : 2
# Frecuencia de  líneas : 1
# Frecuencia de  superiores, : 1
# Frecuencia de  adjudicados : 1
# Frecuencia de  actualmente : 1
# Frecuencia de  tengan : 1
# Frecuencia de  formalizados : 1
# Frecuencia de  y/o : 1
# Frecuencia de  quedaran : 1
# Frecuencia de  comprendidos : 1
# Frecuencia de  circular, : 2
# Frecuencia de  conformidad : 2
# Frecuencia de  artículo : 2
# Frecuencia de  112 : 1
# Frecuencia de  público : 2
# Frecuencia de  caso : 1
# Frecuencia de  si : 1
# Frecuencia de  cumpla : 1
# Frecuencia de  sancionados : 1
# Frecuencia de  han : 1
# Frecuencia de  pagado : 1
# Frecuencia de  multa : 2
# Frecuencia de  les : 1
# Frecuencia de  fue : 2
# Frecuencia de  impuesta : 1
# Frecuencia de  conforme : 1
# Frecuencia de  establecido : 1
# Frecuencia de  mérito, : 1
# Frecuencia de  inhabilitación : 2
# Frecuencia de  subsistirá : 1
# Frecuencia de  hasta : 1
# Frecuencia de  realice : 1
# Frecuencia de  pago : 1
# Frecuencia de  correspondiente, : 1
# Frecuencia de  tercero : 1
# Frecuencia de  113 : 1
# Frecuencia de  vez : 1
# Frecuencia de  transcurrido : 1
# Frecuencia de  pagada : 1
# Frecuencia de  impuesta, : 1
# Frecuencia de  concluirán : 1
# Frecuencia de  efectos : 1
# Frecuencia de  sin : 1
# Frecuencia de  sea : 1
# Frecuencia de  necesario : 1
# Frecuencia de  algún : 1
# Frecuencia de  otro : 1
# Frecuencia de  comunicado, : 1
# Frecuencia de  medio : 1
# Frecuencia de  difusión : 1
# Frecuencia de  atentamente : 1
# Frecuencia de  4 : 1
# Frecuencia de  mayo : 1
# Frecuencia de  2023.- : 1
# Frecuencia de  titular : 1
# Frecuencia de  responsabilidades : 1
# Frecuencia de  licenciado : 1
# Frecuencia de  césar : 1
# Frecuencia de  alejandro : 1
# Frecuencia de  rivera : 1
# Frecuencia de  castillo.- : 1
# Frecuencia de  rúbrica : 1
# Frecuencia de  documento : 1
# Frecuencia de  usted : 1
# Frecuencia de  está : 1
# Frecuencia de  visualizando : 1
# Frecuencia de  puede : 1
# Frecuencia de  haber : 1
# Frecuencia de  texto, : 1
# Frecuencia de  caracteres : 1
# Frecuencia de  u : 1
# Frecuencia de  objetos : 1
# Frecuencia de  muestren : 1
# Frecuencia de  correctamente : 1
# Frecuencia de  debido : 1
# Frecuencia de  conversión : 1
# Frecuencia de  formato : 1
# Frecuencia de  html, : 1
# Frecuencia de  recomendamos : 1
# Frecuencia de  tomar : 1
# Frecuencia de  siempre : 1
# Frecuencia de  referencia : 1
# Frecuencia de  imagen : 2
# Frecuencia de  digitalizada : 1
# Frecuencia de  archivo : 1
# Frecuencia de  pdf : 1
# Frecuencia de  edición : 1
# Frecuencia de  do : 1
# Frecuencia de  lu : 1
# Frecuencia de  ma : 1
# Frecuencia de  mi : 1
# Frecuencia de  ju : 1
# Frecuencia de  vi : 1
# Frecuencia de  sá : 1
# Frecuencia de  crear : 1
# Frecuencia de  búsqueda : 1
# Frecuencia de  avanzada : 1
# Frecuencia de  novedades : 1
# Frecuencia de  top : 1
# Frecuencia de  notas : 1
# Frecuencia de  quejas : 1
# Frecuencia de  sugerencias : 1
# Frecuencia de  obtener : 1
# Frecuencia de  copia : 2
# Frecuencia de  verificar : 1
# Frecuencia de  enlaces : 1
# Frecuencia de  relevantes : 1
# Frecuencia de  contáctenos : 1
# Frecuencia de  filtros : 1
# Frecuencia de  rss : 1
# Frecuencia de  historia : 1
# Frecuencia de  estadísticas : 1
# Frecuencia de  vacantes : 1
# Frecuencia de  gobierno : 1
# Frecuencia de  ex-trabajadores : 1
# Frecuencia de  migratorios : 1
# Frecuencia de  indicadores : 1
# Frecuencia de  tipo : 1
# Frecuencia de  cambio : 1
# Frecuencia de  tasas : 1
# Frecuencia de  08/05/2023 : 1
# Frecuencia de  dolar : 1
# Frecuencia de  17.7863udis : 1
# Frecuencia de  7.776978tiie : 1
# Frecuencia de  28 : 1
# Frecuencia de  dias : 2
# Frecuencia de  11.5625%tiie : 1
# Frecuencia de  91 : 1
# Frecuencia de  11.6385%tiie : 1
# Frecuencia de  fondeo : 1
# Frecuencia de  11.28% : 1
# Frecuencia de  ver : 1
# Frecuencia de  más : 1
# Frecuencia de  encuestas : 1
# Frecuencia de  ¿le : 1
# Frecuencia de  gustó : 1
# Frecuencia de  nueva : 1
# Frecuencia de  página : 1
# Frecuencia de  web : 1
# Frecuencia de  federación? : 1
# Frecuencia de  1 : 1
# Frecuencia de  río : 1
# Frecuencia de  amazonas : 1
# Frecuencia de  62, : 1
# Frecuencia de  col : 1
# Frecuencia de  cuauhtémoc, : 1
# Frecuencia de  c.p : 1
# Frecuencia de  06500, : 1
# Frecuencia de  méxicotel : 1
# Frecuencia de  (55) : 1
# Frecuencia de  5093-3200, : 1
# Frecuencia de  donde : 1
# Frecuencia de  podrá : 1
# Frecuencia de  acceder : 1
# Frecuencia de  nuestro : 1
# Frecuencia de  menú : 1
# Frecuencia de  dirección : 1
# Frecuencia de  electrónica: : 1
# Frecuencia de  www.dof.gob.mx : 1
# Frecuencia de  111 : 1
# Frecuencia de  aviso : 1
# Frecuencia de  legal : 1
# Frecuencia de  algunos : 1
# Frecuencia de  derechos : 1
# Frecuencia de  reservados : 1
# Frecuencia de  © : 1
# Frecuencia de  2022 : 1
